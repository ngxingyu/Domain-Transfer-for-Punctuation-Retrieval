# %% [markdown]
# # Preprocessing

# %%
import pandas as pd
import regex as re

# %%
tedtalks=pd.read_csv('~/data/ted_talks_processed.csv')[['talk_id','transcript']]
len(tedtalks)
# Out:
# 3987

# %%
tedtalks[tedtalks.transcript.map(lambda x:len(x.split())<10)]
# tedtalks.transcript[761]
# Out:
# Empty DataFrame
# Columns: [talk_id, transcript]
# Index: []

# %% [markdown]
# ### Cleaning Text

# %%
parentheses=r'\([^)(]+[^)( ] *\)'
parenthesestokeep=r'\([^)(]+[^)(.!?—\-, ] *\)'
speakertag=r'(?<=[^\w\d \",]) *(?![?\.,!:\-\—\[\]\(\)])(?:[A-Z\d][^\s.?!\[\]\(\)]*\s?)*:(?=[^\w]*[A-Z])'#lookahead keeps semicolon in false cases.
parenthesestoremove=r'\(([^\w]*[^\(\)]+[\w ]+)\):?'
parenthesesaroundsentence=r'\(([^\w]*[^\(\)]+\W*)\):?'
squarebracketsaroundsentence=r'\[([^\[\]]+)\]' #generic since it seems like the square brackets just denote unclear speech.

def displayinstances(col,exp):
    for i in range(len(col)):
    #     temp={x.group() for x in re.finditer( , tedtalks[i])}
        temp={x.group() for x in re.finditer(exp, col[i])}
        if len(temp)!=0:print(i,temp)
    print('--fin--')

''' Identifies term to remove if the words from the previous 
    punctuation (except ") through : until the next word all 
    begins with a caps. Drawback:This doesnt properly capture 
    places where the following term is caps due to it being a 
    proper noun, where the prefix will be removed regardless 
    but will not break the syntax.
'''

def removespeakertags(text):
    return re.sub(speakertag,' ',text)

def removeparentheses(text):
    return re.sub(parenthesestoremove, ' ',text)

def removeparenthesesaroundsentence(text):
    return re.sub(parenthesesaroundsentence,r'\g<1>',text)

def removesquarebrackets(text):
    return re.sub(squarebracketsaroundsentence, r'\g<1>',text)

def removemusic(text):
    text = re.sub(r'♫( *[^♫ ])+ *♫', ' ',text)
    return re.sub(r'♪( *[^♫ ])+ *♪', ' ',text)

def reducewhitespaces(text):
    text=re.sub(r'(?<=[.?!,;:\—\-]) *(?=[.?!,;:\—\-])','',text)
    return re.sub(r'\s+', ' ',text)

def removeemptyquotes(text):
    text= re.sub(r"'[^\w\d]*'",' ',text)
    text= re.sub(r"\([^\w\d]*\)",' ',text)
    text= re.sub(r"\[[^\w\d]*\]",' ',text)
    return re.sub(r'"[^\w\d]*"',' ',text)

def ellipsistounicode(text):
    text = re.sub(r'\.{3,}(?= )','…',text) #ellipsis without trailing punctuation
    return re.sub(r'\.{3,}([^\w\s])','…\g<1>',text) #ellipsis with trailing punctuation

def removenonsentencepunct(text):
    return re.sub(r'[^\w\d\s,.!?;:$#%&^+•=€²£¥…@\-\–\—\/](?!\w)|(?<!\w)[^\w\d\s,.!?;:$#%&^+•=€²£¥…@\-\–\—\/]',' ',text)

def combinerepeatedpunct(text):
    newtext=[text,re.sub(r'([^\w\d]+) *\1+','\g<1> ',text)]
    i=1
    while (newtext[0]!=newtext[1]):
        i+=1
        newtext[i%2]=re.sub(r'([^\w\d]+) *\1+','\g<1> ',newtext[(1+i)%2])
    return newtext[i%2]

def preprocess(tedtalks):
    print('removing speaker tags')
    tedtalks=tedtalks.apply(removespeakertags)
    
    print('removing non-sentence parenthesis')
    tedtalks=tedtalks.apply(removeparentheses)
    
    print('removing parenthesis')
    tedtalks=tedtalks.apply(removeparenthesesaroundsentence)
    
    print('removing square brackets')
    tedtalks=tedtalks.apply(removesquarebrackets)
    
    print('removing music lyrics')
    tedtalks=tedtalks.apply(removemusic)
    
    print('removing empty tags')
    tedtalks=tedtalks.apply(removeemptyquotes)
    
    print('change to unicode ellipsis')
    tedtalks=tedtalks.apply(ellipsistounicode)
    
    print('removing non-sentence punctuation')
    tedtalks=tedtalks.apply(removenonsentencepunct)
    
    print('combine repeated punctuation')
    tedtalks=tedtalks.apply(combinerepeatedpunct)
    
    print('reduce whitespaces')
    tedtalks=tedtalks.apply(reducewhitespaces)
    
    print('--done--')
    return tedtalks

# %%
tedtalks.transcript=preprocess(tedtalks.transcript)
# displayinstances(tedtalks,'[^\w\d\s]{2,}')
# displayinstances(tedtalks,r'[^\w\d\s,.!?;:$#%&^+•=€²£¥…@\-\–\—\/](?!\w)|(?<!\w)[^\w\d\s,.!?;:$#%&^+•=€²£¥…@\-\–\—\/]')
# displayinstances(tedtalks,r"' ")
# tedtalks[1148]
# Out:
# removing speaker tags
# removing non-sentence parenthesis
# removing parenthesis
# removing square brackets
# removing music lyrics
# removing empty tags
# change to unicode ellipsis
# removing non-sentence punctuation
# combine repeated punctuation
# reduce whitespaces
# --done--

# %%
# tedtalks=tedtalks[tedtalks.transcript.apply(lambda x:len(x.split()))>4]
tedtalks
# Out:
#       talk_id                                         transcript
# 0           1  Thank you so much, Chris. And it's truly a gre...
# 1          92  About 10 years ago, I took on the task to teac...
# 2           7   Hello voice mail, my old friend. I've called ...
# 3          53  If you're here today — and I'm very happy that...
# 4          66  Good morning. How are you? Good. It's been gre...
# ...       ...                                                ...
# 4000    62678   I'm 14, and I want to go home. My name is Bet...
# 4001    62782  In 1905, psychologists Alfred Binet and Théodo...
# 4002    62263  Picture yourself driving down the road tomorro...
# 4003    62784  In early 1828, Sojourner Truth approached the ...
# 4004    62794  Can you guess what you’re looking at? Is it a ...
#
# [3990 rows x 2 columns]

# %%
import xml.etree.ElementTree as ET
tree=ET.parse('/home/nxingyu/data/OpenSubtitles/raw/en/2012/2402471/4682144.xml')
# tree=ET.parse('/home/nxingyu/data/OpenSubtitles/raw/en/1497/3204044/5919971.xml')
rows=[]
for child in tree.getroot():
    rows.append(''.join([x.strip() for x in list(child.itertext())]))
' '.join(rows[:-1])
# Out:
# '(Police radio chatter) (Radio chatter continues, indistinct conversations) (Exhales) (Indistinct conversations) (Shutter clicking) Hey, Jane. Got a positive I.D. on the victim. Viktor Mendelssohn. 62. He was a diamond cutter. He has a shop in the San Francisco Diamond district. Same as it ever was-- more bodies, more death. Not exactly the same. This one was eviscerated with an electric rotary saw. Huh. Excuse me. Your toe. Careful. Sorry. Is it me, or does Jane seem a little bit off since the feds took Lorelei? Well, he spent six months setting a trap for Red John. He has nothing to show for it. How would you feel? Maybe we should invite him out for a night with the boys. (Sighs) All right, you ask him. (Clicks, flame whooshes) Well, I-I came out this morning to snip my herbs. It\'s always best to do that right after the morning dew evaporates. (Voice breaking) And when I didn\'t see Viktor, I got a really bad feeling. Do you usually see him in the morning? Every morning. We chat over the fence. Hey. Jane, this is Betty Fulford. Hey. She lives next door. Patrick Jane. So did Viktor tell you about anybody who might want to hurt him? No! Although... last night when I was getting ready for bed, I did hear him arguing with a man in his house. What were they arguing about? Flowers. Really? Blue orchids, to be exact. They--they were shouting, and Viktor never shouts. And you were in your bedroom at this time? That\'s right. That\'s right. My window was open. Did you happen to catch a glimpse of the other man? Well, I tried to snoop, but I couldn\'t see into the kitchen. That\'s where they were having it out. (Teapot whistling) What\'s that noise? I have absolutely no idea, but I will investigate. (Continues whistling) (Whistling stops) (Mutters indistinctly) Mm. (Clatters) (Rattles) (Rattles) (Rattles) (Rattles) (Rattles) (Rattles) (Slams lid) (Teacup shatters) Everything okay in there? (Patrick) Everything\'s fine! It\'s all peachy. (Rattles) What are you doing in there? (Giggles) ♪ The Mentalist 5x02 ♪ Devil\'s Cherry Original Air Date on October 7, 2012 == sync, corrected by elderman == Ohh. Rabbit stew. Yummy. We need to fatten you up. Hello. Hmm? What time did you get to the house this morning? Same time every Monday. 8:30. I walk from the bus stop. Do you have a key to the house? No. Mr. Mendelssohn let me in. But this morning, he didn\'t answer the door, so I looked in the window. Well, you did the right thing. Calling the police-- very brave. Very brave. I told Mr. Mendelssohn something bad was coming, but he didn\'t listen to me. Why did you think something bad was on its way? The black ants. For two weeks I come now, and I clean black ants from the house. Black ants? In some South American countries it\'s said that if black ants enter your house, then someone in your family might die. Ay. Gracias a dios. You understand. Si. Si. This is... an eagle\'s claw. It will help you find who did this. Oh. Take it, please. Okay. Thank you. I will. I\'ll just-- no te olvides. Okay. Thank you. Ooh. Oops. Excuse me. (Police radio chatter) Bunny? Where\'s the bunny? Here. Rigsby, hold this. Has anyone seen a rabbit around here? Excuse me. Uh, did you happen to see a rabbit? Ja. Thank you. (Door creaks) Hello, fella. Yeah? There... Ahh, there you are. Huh? Gotcha. Fella. You found him. I take it this belongs to you. Yeah. It\'s the third time he\'s escaped. Chews through that metal like a floppy-eared rat. Thanks for finding him. Oh. Pleasure. Certainly took your time getting here. You were expecting me? Yeah, of course. You know something about the murder? Yeah. Poor old Mr. Mendelssohn. You know anything that could help us? You tell me. How can I know what you know? How can I know what I know will help you? You\'re testing me. Why? You don\'t have issues with authority figures. You know you\'re the smartest person in most rooms. What\'s your name? Am I required to tell you? Well, I\'m just a consultant. You don\'t have to tell me anyt ...

# %%
for c in ".?!,;:-—":
    print(c,sum(tedtalks.transcript.str.count("\\"+c)))
# Out:
# . 410157
# ? 36774
# ! 3277
# , 494575
# ; 5846
# : 12950
# - 38065
# — 33375

# %%
# opensubtitles=pd.read_csv("./data/opensubtitles.csv",sep=',',names=['filenames','transcript'])
# opensubtitles
displayinstances(tedtalks.transcript,'[.?!,;:\—]{2,}')
# displayinstances(tedtalks.transcript,'\w+[.?!,;:\—] +[.?!,;:\— ]+ +[A-Z][a-z]+')
# Out:
# 7 {'!?'}
# 12 {'!—', '.—', '.,'}
# 21 {'?—'}
# 22 {'.,'}
# 24 {'.—'}
# 28 {'?—'}
# 29 {'?—'}
# 32 {'.,'}
# 42 {'?—'}
# 45 {'.,'}
# 46 {'!—'}
# 55 {'.,'}
# 58 {'.,'}
# 59 {'.—'}
# 60 {'!—'}
# 61 {'.,'}
# 66 {',—'}
# 68 {'.,'}
# 78 {'.,'}
# 82 {'.,'}
# 84 {'!—'}
# 85 {'.—'}
# 86 {'.—', '.,'}
# 92 {'.—'}
# 93 {'.—'}
# 97 {'.—', '.,'}
# 104 {'.,', '.:'}
# 119 {'.,'}
# 125 {'.,', '?—'}
# 133 {'.,'}
# 134 {'?—'}
# 135 {'.,'}
# 139 {'.,'}
# 141 {'.,'}
# 142 {'?.', '.,'}
# 149 {'?—'}
# 152 {'!—'}
# 168 {'.,', '—,'}
# 170 {'!—'}
# 174 {'?—'}
# 176 {'?—'}
# 182 {'.,'}
# 183 {'!—', '?!'}
# 186 {'?!'}
# 192 {'?—'}
# 193 {'!—'}
# 195 {'.,'}
# 196 {'!—', '.,', '—?', '.?'}
# 197 {'.,'}
# 198 {'.,'}
# 209 {'.,'}
# 210 {'.—', '.,'}
# 212 {'!—'}
# 225 {'.,'}
# 227 {'.,'}
# 231 {'.—'}
# 232 {'.,', '.?.'}
# 236 {'.,'}
# 241 {',—'}
# 243 {'.,'}
# 244 {'.,'}
# 264 {'.,'}
# 270 {'?—'}
# 271 {'.,'}
# 275 {'.,'}
# 281 {'!—', '?—'}
# 282 {'.,'}
# 283 {'.,'}
# 286 {'!—'}
# 290 {'.,'}
# 292 {':.'}
# 298 {'.,'}
# 306 {'.—', '.,'}
# 309 {'.—', '.,'}
# 311 {'.,'}
# 312 {'—?'}
# 316 {',—', '.—'}
# 317 {',—'}
# 320 {'.—', '.,'}
# 321 {'.,'}
# 323 {'.,'}
# 325 {'.,'}
# 333 {'!—'}
# 337 {',—'}
# 342 {',—'}
# 344 {'!—'}
# 347 {'?—'}
# 348 {':—'}
# 351 {'.,', '?—', '.?'}
# 352 {'.,'}
# 353 {'.,'}
# 354 {'.,'}
# 357 {'.?'}
# 360 {'.;', '.,', '?—'}
# 362 {',;'}
# 366 {'.,'}
# 370 {'.,'}
# 371 {'.,'}
# 372 {',—'}
# 375 {'.,'}
# 378 {'!—'}
# 385 {'?—', '?;'}
# 387 {'.—'}
# 388 {',—', '!—'}
# 389 {'.,'}
# 390 {'.,'}
# 393 {':—'}
# 397 {'.,'}
# 401 {'—?'}
# 404 {'!—'}
# 406 {':.'}
# 412 {',—'}
# 414 {'.,', '.?'}
# 416 {'.,', ',.'}
# 419 {'.—'}
# 420 {'?—'}
# 430 {'?—'}
# 443 {'.,'}
# 449 {'.,'}
# 452 {'.,'}
# 457 {'!?'}
# 471 {'.,'}
# 473 {'.,'}
# 478 {'.,'}
# 486 {'.,'}
# 490 {',—'}
# 494 {'?—'}
# 495 {',.', '?—'}
# 497 {'.:'}
# 498 {'.,'}
# 501 {'?—'}
# 507 {'.,'}
# 513 {',—'}
# 514 {'.,'}
# 522 {'.,'}
# 524 {'.,'}
# 530 {'.,'}
# 536 {'!,'}
# 539 {'!—'}
# 541 {'.—'}
# 542 {'.,'}
# 544 {'.,'}
# 545 {'.,'}
# 552 {'.,'}
# 559 {'.,'}
# 582 {'?—'}
# 584 {'.,', '.?'}
# 586 {'.,'}
# 587 {'.,'}
# 589 {'.,'}
# 598 {'.,'}
# 608 {'.,'}
# 616 {'!,'}
# 619 {'?—'}
# 621 {'.,'}
# 624 {'.,'}
# 630 {'.,'}
# 631 {'!—'}
# 633 {'!—'}
# 637 {'?—'}
# 639 {'.,'}
# 640 {'.,', '.?'}
# 641 {'.,'}
# 642 {'.,'}
# 643 {'?—'}
# 646 {'?—'}
# 662 {'.—'}
# 669 {'.,'}
# 684 {'.,'}
# 685 {'?—'}
# 690 {'.,'}
# 691 {'.,'}
# 693 {'.,', '?—'}
# 698 {'.,', '?—'}
# 702 {'.,', '.?'}
# 705 {'.:'}
# 711 {'.,'}
# 712 {'.,'}
# 713 {'.,'}
# 717 {'.,'}
# 719 {'?—'}
# 720 {'!.', '!,'}
# 723 {'!—'}
# 725 {'?—'}
# 726 {'.,'}
# 727 {'.,'}
# 728 {'!—'}
# 735 {',—'}
# 736 {'.,'}
# 738 {'?—'}
# 739 {',—'}
# 740 {',—', '.,'}
# 746 {'.—'}
# 752 {'.,'}
# 754 {'.,'}
# 755 {'.,'}
# 763 {'.—'}
# 765 {'?—'}
# 772 {'.;', '.,'}
# 776 {'.,'}
# 777 {'.,'}
# 778 {'.,'}
# 784 {'.—'}
# 788 {'.—'}
# 789 {',—'}
# 799 {'.,'}
# 801 {'?—'}
# 806 {'.—'}
# 807 {'.—'}
# 811 {'?—'}
# 817 {':—'}
# 824 {'.,'}
# 825 {'.,'}
# 826 {',—'}
# 827 {'.—'}
# 829 {'?—'}
# 832 {'?—'}
# 834 {'?—'}
# 844 {'.,'}
# 855 {'.,'}
# 865 {'.,', '?—'}
# 882 {'.;'}
# 887 {'.,'}
# 892 {'.—'}
# 897 {'.,', '?—'}
# 908 {'.,'}
# 923 {'?—'}
# 927 {'.—'}
# 928 {',—', '?—'}
# 929 {'.,'}
# 934 {'.,', '.?'}
# 936 {'.—'}
# 944 {'.—'}
# 946 {'.—', '.,', '.?'}
# 952 {'.,'}
# 956 {'?—'}
# 962 {'?—'}
# 973 {'?,'}
# 984 {'.,'}
# 987 {'.—', '.,'}
# 988 {'.,'}
# 991 {'.,', '?—'}
# 993 {'.,'}
# 994 {'.—'}
# 996 {'?—'}
# 997 {'!—', '?!', '?—'}
# 1000 {'.—'}
# 1001 {'.,'}
# 1014 {'?—'}
# 1027 {'?—'}
# 1040 {',—'}
# 1045 {'.—', '.,'}
# 1055 {'.,'}
# 1063 {'.,'}
# 1065 {'.,'}
# 1066 {'!—', '.,'}
# 1072 {'!—', '?—'}
# 1080 {',—'}
# 1092 {'.,'}
# 1094 {'.,'}
# 1095 {'?—'}
# 1099 {'.,'}
# 1102 {'.,', '?—'}
# 1106 {'?—'}
# 1108 {'!—', '?,'}
# 1120 {'?—'}
# 1123 {'!—'}
# 1124 {'.,'}
# 1125 {'.,'}
# 1127 {'.,'}
# 1133 {',—'}
# 1137 {'!—'}
# 1138 {'?—'}
# 1139 {'.,'}
# 1145 {'?!'}
# 1147 {'?—'}
# 1151 {'?—'}
# 1162 {'.,'}
# 1163 {'.,'}
# 1166 {'.,'}
# 1172 {'?—'}
# 1186 {'?,'}
# 1187 {'.,'}
# 1188 {'.,'}
# 1189 {'.,'}
# 1196 {'.—'}
# 1197 {'.,'}
# 1199 {'?—'}
# 1202 {',—'}
# 1204 {'!—'}
# 1208 {'.,', '?—'}
# 1212 {',—'}
# 1213 {'.—'}
# 1220 {'.,'}
# 1229 {',—'}
# 1231 {',—'}
# 1232 {'.,'}
# 1234 {'.,'}
# 1244 {'?—'}
# 1245 {'!—', '.,'}
# 1252 {'.,'}
# 1258 {'.,'}
# 1263 {'!—'}
# 1266 {'.,'}
# 1271 {'.,'}
# 1274 {',—'}
# 1279 {'?,'}
# 1283 {'.,'}
# 1286 {'.,'}
# 1287 {'.,'}
# 1288 {'!—'}
# 1290 {'.,'}
# 1291 {'?!', '?—'}
# 1294 {'?—', '—?'}
# 1296 {'.,'}
# 1299 {'.,'}
# 1301 {'.,', '!—', '?—'}
# 1305 {'.,'}
# 1306 {'.,'}
# 1307 {'.,'}
# 1313 {'!—'}
# 1316 {'.,'}
# 1318 {',—'}
# 1319 {'.,'}
# 1324 {'—?'}
# 1325 {'.,'}
# 1330 {'!—'}
# 1333 {'.,'}
# 1337 {'.—'}
# 1346 {'.—'}
# 1347 {'!—', '.,'}
# 1348 {'.—'}
# 1350 {'.,'}
# 1355 {'!—'}
# 1356 {'?—'}
# 1361 {'.,'}
# 1364 {'.,'}
# 1366 {'!—'}
# 1372 {'.,'}
# 1373 {'.,'}
# 1374 {'.,', '?—'}
# 1377 {'?—'}
# 1381 {'.,', ':—', '?—'}
# 1387 {'.,'}
# 1389 {'.,'}
# 1392 {'?—'}
# 1394 {'.,'}
# 1395 {'.,'}
# 1406 {':.', ',.'}
# 1415 {'.—'}
# 1419 {'.—'}
# 1421 {'.,'}
# 1423 {'!—'}
# 1431 {'!—'}
# 1433 {'?—'}
# 1434 {'.,'}
# 1442 {',—'}
# 1449 {'.—'}
# 1451 {'.,'}
# 1458 {'.—'}
# 1463 {'.,'}
# 1464 {'.,'}
# 1466 {',—'}
# 1470 {'.—'}
# 1487 {'.,'}
# 1489 {'.,'}
# 1490 {'.,'}
# 1498 {'.,'}
# 1500 {':—'}
# 1502 {'.,'}
# 1503 {'?—'}
# 1504 {'?!', ':—'}
# 1508 {'.,', '?—'}
# 1509 {'.,'}
# 1512 {'.,'}
# 1515 {'.,'}
# 1519 {'.,'}
# 1521 {'.,'}
# 1531 {'.,'}
# 1533 {'.,'}
# 1534 {'.,'}
# 1535 {'.,'}
# 1536 {'.,', '?—'}
# 1537 {'.?'}
# 1539 {'.,'}
# 1542 {'.,'}
# 1546 {'.,'}
# 1547 {'.,'}
# 1551 {'.,'}
# 1560 {'.—'}
# 1566 {'.,'}
# 1570 {'.,'}
# 1579 {'.;', '.,'}
# 1580 {'.,'}
# 1581 {'.,'}
# 1587 {'?.'}
# 1589 {'.,', '?—'}
# 1591 {'.,'}
# 1594 {'.—'}
# 1596 {'.,'}
# 1599 {'.,'}
# 1602 {'.,'}
# 1612 {'.,'}
# 1614 {'.,'}
# 1620 {'.,', '?—'}
# 1621 {'?—'}
# 1622 {'.,'}
# 1630 {',.'}
# 1631 {'.,'}
# 1632 {'?—'}
# 1636 {'.,'}
# 1637 {'.,'}
# 1638 {'.,'}
# 1639 {'?—'}
# 1640 {'.,'}
# 1649 {'.,'}
# 1656 {'.,'}
# 1663 {'.,', '!,'}
# 1676 {'.,', ':—'}
# 1678 {'.,'}
# 1685 {'.?'}
# 1699 {'.,'}
# 1706 {'.,'}
# 1712 {'!—'}
# 1716 {'.,'}
# 1717 {'.—', ':—'}
# 1719 {'.,'}
# 1721 {'?—'}
# 1732 {'.,'}
# 1735 {'.,'}
# 1743 {'.,'}
# 1752 {'.,'}
# 1753 {'!—'}
# 1754 {'.,'}
# 1757 {'.,'}
# 1758 {'.,'}
# 1759 {'.,'}
# 1760 {'.,'}
# 1769 {'.,'}
# 1772 {'.,'}
# 1789 {'.,'}
# 1791 {'?—'}
# 1795 {'.,'}
# 1796 {'.,'}
# 1797 {'.,'}
# 1801 {'.,'}
# 1806 {'.,'}
# 1809 {'.,'}
# 1813 {'.,'}
# 1814 {'.,'}
# 1824 {'.,'}
# 1827 {'.,'}
# 1832 {'.,', '?—'}
# 1841 {'.,'}
# 1845 {'.,'}
# 1846 {'!?', '.,', '.?'}
# 1848 {'.,'}
# 1853 {'.,'}
# 1855 {'.,'}
# 1856 {'.,'}
# 1862 {'.,'}
# 1865 {'.,'}
# 1866 {'.,'}
# 1877 {'.,'}
# 1879 {'.,'}
# 1886 {'.—'}
# 1898 {'!—', '.,'}
# 1900 {'!—'}
# 1902 {'.,'}
# 1911 {'.,'}
# 1912 {'.,'}
# 1914 {'?—'}
# 1916 {'.,'}
# 1918 {'.,'}
# 1926 {'—?'}
# 1929 {'.;', '.,'}
# 1931 {'.?'}
# 1944 {'?!?'}
# 1945 {'.,'}
# 1954 {'?,'}
# 1961 {'?—'}
# 1984 {'!—'}
# 2002 {'!—'}
# 2016 {'.—'}
# 2023 {'?—'}
# 2031 {'!—'}
# 2037 {':—'}
# 2045 {',—', '!—'}
# 2047 {'?—'}
# 2056 {'!—'}
# 2060 {'?,'}
# 2071 {'.—'}
# 2084 {'.,', '?—'}
# 2093 {'?,'}
# 2098 {'?!'}
# 2104 {'.?'}
# 2105 {'!—'}
# 2109 {',—'}
# 2111 {'?,'}
# 2115 {'.,'}
# 2146 {'!—'}
# 2149 {',—'}
# 2151 {'.,'}
# 2159 {':.'}
# 2173 {'!:'}
# 2178 {'!—'}
# 2179 {'.,'}
# 2180 {':,'}
# 2181 {'.,'}
# 2184 {'?—'}
# 2193 {',—'}
# 2208 {'?—'}
# 2211 {'?—'}
# 2238 {'.,'}
# 2243 {'!—'}
# 2270 {'.,', '?,'}
# 2278 {'?—'}
# 2284 {'?—'}
# 2293 {'!—'}
# 2304 {'?,'}
# 2305 {'.,'}
# 2323 {',—'}
# 2325 {',—', '!—'}
# 2329 {'.,', '.?'}
# 2339 {'?—'}
# 2391 {'.,'}
# 2404 {',—'}
# 2409 {'!?'}
# 2417 {'?—'}
# 2436 {'.,'}
# 2450 {'?—'}
# 2458 {'?—'}
# 2472 {'.,'}
# 2481 {'.,'}
# 2482 {'.,'}
# 2490 {'.—'}
# 2495 {'?—'}
# 2497 {'.,'}
# 2503 {'?—'}
# 2528 {'!—'}
# 2545 {'?!'}
# 2560 {'!—'}
# 2572 {'?!'}
# 2592 {'?—'}
# 2600 {'?,'}
# 2603 {'!—'}
# 2651 {'.,'}
# 2652 {'—?'}
# 2666 {'?—'}
# 2673 {'.,'}
# 2678 {'.—'}
# 2692 {'.,'}
# 2698 {',—'}
# 2704 {'!?', '?!'}
# 2705 {'?,'}
# 2717 {'!—'}
# 2760 {'!—'}
# 2781 {'.,'}
# 2783 {',—', '.—'}
# 2794 {'?—'}
# 2819 {'.,'}
# 2821 {'!—'}
# 2835 {'!?', '.!'}
# 2897 {'!—', '.,'}
# 2908 {'.,'}
# 2910 {'!,'}
# 2913 {'?!'}
# 2955 {'?,', '!,'}
# 2966 {'!—'}
# 2994 {'.—'}
# 3004 {'?,'}
# 3008 {'?,'}
# 3009 {'.—'}
# 3026 {'.,'}
# 3029 {'?—'}
# 3047 {'?—'}
# 3067 {'.,'}
# 3126 {':.'}
# 3132 {'.,'}
# 3144 {'.,'}
# 3150 {'.,'}
# 3174 {'!—'}
# 3175 {'.,'}
# 3193 {'.,'}
# 3197 {'.,'}
# 3215 {'.,'}
# 3223 {'.,'}
# 3304 {'?—'}
# 3306 {'!—'}
# 3371 {',—', '?,'}
# 3376 {'!—'}
# 3394 {'.,'}
# 3434 {'!—'}
# 3435 {'.,'}
# 3438 {'?—'}
# 3452 {'?—'}
# 3470 {'.,'}
# 3493 {'.,'}
# 3501 {'?—'}
# 3540 {'.,'}
# 3551 {'?,'}
# 3567 {'?—'}
# 3580 {'.,'}
# 3624 {'.,'}
# 3626 {'!—'}
# 3650 {'?—'}
# 3656 {'.,'}
# 3684 {'!—'}
# 3705 {'—.'}
# 3709 {'?—'}
# 3710 {'!—'}
# 3726 {'?—'}
# 3728 {'.,'}
# 3745 {'?—'}
# 3750 {'.—', '.,'}
# 3769 {'.—', '.,'}
# 3841 {'.,'}
# 3879 {'?—'}
# 3887 {'?!'}
# 3964 {',—'}
# 3976 {'?,'}
# --fin--

# %%
displayinstances(tedtalks.transcript,'[\w\d]+ *\- *[\w\d]+')
# Out:
# 0 {'G-V', 'limited-use', 'Low-cost', 'end-use', 'low-hanging', 'click-through', 're-brand', 'I-40', 'low-cost', 're-purposed', 'consumer-friendly', 'hot-button', '30-second', 'rear-view', '28-second', 'carbon-neutral', 'short-term', 'beach-combing'}
# 1 {'hypothesis-generating', 'sub-Saharan', 'high-income', 'well-used'}
# 2 {'Uh-uh', 'sub-menus', '9-1', 'add-ons', 'log-off', 'drop-down', 'real-world', 'un-retouched', 'pop-up', 'Pre-sweat'}
# 3 {'top-down', 'day-to', 'hard-earned', 'green-collar', 'on-street', 'community-friendly', 'walk-to', 'well-loved', 'third-world', 'highway-expansion', 'land-use', 'urban-planning', 're-envision', 'working-class', 'street-end', 'hyper-exploit', 'Red-lining', 'first-phase', 'good-looking', 'anti-development', 'mass-transit', 'post-graduate', 'well-paying', 'big-box', 'one-and', 'environmentally-challenged', 'seed-grant', 'people-first', 'food-distribution', 'community-led', 'rapidly-growing', 'Low-income', 'well-meaning', 'post-Katrina', 'low-income', 'off-limits', 'petroleum-based', 'highly-reflective', 'a-quarter', 'triple-bottom', 'emergency-room', 'end-of', 'decision-making', 'highly-influential', 'cost-benefit', 'hip-hop'}
# 4 {'strip-mine', 'Stratford-on', 'T-shirts', 'high-water', 'T-shirt', 'oak-paneled', 'open-heart', 'out-of', 'four-year'}
# 5 {'rapid-fire', 'developer-driven', 'front-of', 'off-center', 'open-air', 'x-ray', 'left-hand', 'mixed-use', 'off-season', 'Two-thirds', 're-digest', 'hyper-rational', 'one-third', 'stair-stepping', 'brand-new', 'I-64', 'high-budget', 'multi-form', '100-year', 'super-efficient', 'sub-building', 'back-of'}
# 6 {'cut-off', 'age-of', 'second-grade', 'Latter-day', 'short-sleeved', 'fresh-faced', 'change-of'}
# 7 {'self-interest', 'non-stop', 'food-finding', 'co-discoverer'}
# 8 {'self-centered', 'best-selling', 'father-in', 'hours-a', 'no-brainer', 'year-old', 'All-Stars', 'purpose-driven', 'self-worth', 'mid-80s', 'month-long'}
# 9 {'five-second', '18-year', 'love-hate', 'Egyptian-Lebanese', '12-year', 'garbage-collecting', 'non-violence', 'Bat-Chen', 'off-screen', 'one-sentence'}
# 10 {'three-piece', 'house-to', 'human-to', 'bio-error', 'just-in', 'non-governmental', 'pandemic-to', 'early-warning', 'bio-terror'}
# 11 {'KwaZulu-Natal', 'pre-existing', 'own-clinic', 'pre-Katrina', 'op-eds', 'eat-your', 'Open-source', 'on-site', 'gray-haired', 'leap-back', 'technology-based', 'needs-based', 'multi-lingually', 'self-sustaining', 'community-designed', 'tree-hugging', 'open-source', '370-dollar', 'sky-scraping', 'mid-20s', 'best-designed', 'sub-Saharan'}
# 12 {'post-office', 'so-called', 'one-third', 'sales-and', 'parent-teacher', 'child-to'}
# 13 {'false-colored', 'multi-user', 'open-source', 'pressure-sensitive', 'multi-touch', 'rear-projected', 'two-finger', 'hyper-spectral', 'low-cost', 'high-resolution', 'light-box', 'mouse-and', 'plug-ins', 'two-fingered', 'windows-pointer', 'multi-point'}
# 14 {'19th-century', 'two-page', 'E-G', 'A-B'}
# 15 {'multi-dimension', '16th-century'}
# 16 {'non-zero', 'Water-borne', 'field-tested', 'charcoal-making', 'micro-finance', 'water-treatment', 'five-gallon', 'low-cost', 'pre-briquetted', 'trade-offs', 'small-scale', 'micro-enterprise', 'side-by', 'macro-tubes'}
# 17 {'solar-powered', '18-minute', 'carbon-fiber', 'Single-surface', 'bio-polycarbonate', 'X-light', 'inspired-by', 'socio-erotic', 'self-inspirational', 'self-inspired', 'single-surface', 'brand-new', 'gas-injected', 'one-piece', 'three-wheeled', 'vacuum-formed', 'filtered-down', 'fat-free', 'watered-down', 'carbon-nylon', '21st-century', 'ever-greater'}
# 18 {'all-volunteer', 'Western-European', 'top-50', 'semi-professionals', 'close-knit', 'real-time', 'neo-Nazi', 'non-negotiable', 'Bush-Kerry', 're-elected', 'one-third', 'part-time', 'tight-knit', 'English-centric', 'full-time', 'self-monitor', 'open-ended', 'non-commercially', 'AOL-style', 'off-line', 'decision-making', 'long-standing'}
# 19 {'six-and', 'K-12', 'the-middle', 'shut-out', 'single-authored', 'on-demand', 'community-authored', 'book-type', 'open-content', 'e-texts', 'cut-out', 'mark-up', 'no-nonsense', 'a-half', 'world-flattening', 're-sampling', 'human-readable', 'open-source', 'lingerie-selling', 're-contextualize', 'peer-review'}
# 20 {'difficult-to', '11-year', 'guru-ship', 'low-threshold', 'post-war'}
# 21 {'Twenty-nine', 'great-grandfather', 'one-pound', 'one-day', 'great-great', 'great-grandchildren', 'nerve-racking'}
# 22 {'post-industrial', 'eighth-century', 'long-term', 'serotonin-enhancing', 'step-by', 'counter-trend'}
# 23 {'Mercedes-Benz', 'Asian-American', 'Coca-Cola', 'dried-up', 'upper-middle', 'V-Day', 'cream-eating', 'Native-American', 'vagina-friendly', 'full-length', 'V-world', 'high-powered', 'un-sexy', 'V-wave', 'AK-47', 'date-raped', '40-some', 'African-American', 'closing-off', 'testosterone-filled', 'gang-raped'}
# 24 {'smell-oriented', 'middle-sized', 'medium-sized', 'second-guess', 'day-flying', 'many-worlds', 'Middle-World', 'goings-on', 'child-murderer', 'blame-worthiness', 'Middle-Worlders', 'goal-seeking', 'medium-scaled', 'make-believe', 'tension-dominated', 'neuro-anatomy', 'neutrino-sized', 'three-dimensional', 'counter-revenge', 'horn-shaped'}
# 25 {'open-ended', 'problem-avoidance', 'ever-increasing', 'self-contained', 'light-years', 'problem-fixing', 'present-day', 'high-resolution', 'point-blank', 'knowledge-based', 'quasi-stellar', 'life-bearing'}
# 26 {'Extra-Chunky', 'red-tail', 'tomatoey-ness', 'extra-chunky', 'eight-ounce', 'take-home'}
# 27 {'gold-plated', 'mid-to', 'extra-chunky', 'four-square', '50-an', 'co-author', '80-hour', 'real-real', 'well-being', 'part-time', 'million-dollar', 'dark-skinned', 'bling-bling', 'mid- 80s', 'drug-selling', 'co-authoring', 'fake-real', 'late- 80s', 'African-American', 'two-person', 'inner-city', 'stripped-down', 'first-year', '14-year', 'well-documented'}
# 28 {'two-thirds', 'one-and', 'one-question', 'Sixty-six', 're-rank', 'a-quarter', 'Wrong-o', 'three-pound', '50-year', 'black-and'}
# 29 {'seventy-five', 'difficult-to', 'Pareto-improving', 'acid-washed', 'off-chance', 'Do-It', 'best-fitting', 'decision-making', 'bad-fitting', 'extra-virgin'}
# 30 {'fine-tune', 'anti-tumor', 'bumpy-looking', 'growth-promoting', 'micro-metastases', 'far-fetched', 'anti-angiogenic', '14-year', 'black-and', 'fine-tuned'}
# 31 {'150-year', 'middle-aged', '200-year', 'seven-and', 'ongoing-ly', '000-year', 'non-aging', 'a-half', 're-draw', 'middle-age', 'short-lived', 'pro-aging', 'first-generation', 'age-related', 'self-repair', 'short-term', 'long-lived', '80-year'}
# 32 {'mini-blueprints', 'five-year', 'micro-level', 'how-to', 'us-and', '25-year', 'five-dollar', 'long-lasting', 'lean-to', '000-dollar', 'three-walled', 'micro-finance', 'quarter-acre', 'large-scale', '15-dollar'}
# 33 {'man-years', 'oil-rich', 'know-how', '500-page', 'man-months'}
# 34 {'vis-a', '10- to', '20-year', 'micro-production', 't-shirt', 're-engage'}
# 35 {'re-tape', '000-dollar', 'slow-motion'}
# 36 {'three-year', 'highest-performance', 'the-line', 'capitalist-like', 'higher-speed', '10-year', 'three- to', 'top-of', '15-year', 'sub-orbital', '14-year', 'four-year', 'flight-testing'}
# 37 {'seven-and', 'low-tech', 'A-S', 'one-and', 'a-half', 'Orde-Lees', 'two-way', 'five-and', 'sawn-off', 'vodka-fueled', 'K-R', 'bio-mimicry', 'high-tech', 'hand-knitted', 'co-pilot', 'sub-two', 'all-clear'}
# 38 {'the-art', 'pre-puberty', 'bombed-out', 'world-changing', 'bottom-up', 'wide-open', 'ground-up', 'full-size', 'urban-renewal', 'e-waste', 'half-a', 'Bio-mimicry', 'high-density', 'high-tech', 'air-conditioning', 'coal-burning', 'hour-and', 'a-half', 're-invent', 'blue-collar', 'high-rises', 'five-level', 'pre-going', 'state-of', 'coal-mining', 're-strategize', 'in-school', 'catch-up', 'labor-intensive', 'fine-art', 'high-end', 'single-family', 'energy-saving', 'third-world'}
# 39 {'single-spaced', 'mid-brain', 'gun-like', 'obsessive-compulsive', 'flat-line', 'doo-doo', 'neuro-pacemaker', '000-dollar', 'electro-stimulation', 'high-tech', 'long-term'}
# 40 {'mind-blowing', 'Six-and', 'a-half', 'anti-retrovirals', 're-describe', 'Haight-Ashbury', 'life-saving', 'long-distance', 'know-how', 'anti-retroviral', 'ex-hippies'}
# 41 {'non-science', 'fine-grain', '1940s-era', 'government-approved', 'op-ed', 'pattern-seeking', 'coin-flip', 'story-sized', 'pseudo-science', 'well-defined', 'high-tech', 'close-up', 'non-sense', 'cease-and', 'right-leaning', 'light-years', 're-cut', 'black-and', 'multi-dimensional', 'high-school', 'coarse-grain'}
# 42 {'in-joke', 'type-1', 'Head-tail', 'two-minute', 'long-lost', 'head-tail', 'type-2', 'non-smoking', 'high-risk', 'pre-warned', 'nation-states', 'take-home', 'A-G', 'G-A'}
# 43 {'solar-powered', 'add-to', 'your-cart', 'stone-age', 'pro-technology', 'self-expression', 'brand-new', 'evolutionary-type', 'non-technology', 'co-developer', 'long-distance', 'brown-green', 'co-evolution', 'general-purpose', 'long-term', 'one-click'}
# 44 {'E-commerce', 'Haight-Ashbury', 'reverse-engineering', 'paradigm-shift', 'two-to', 'electro-mechanical', 'out-performing', 'high-tech', 'human-like', 'nano-engineered', 'the-25th', 'self-replicating', 'inter-neural', 'virtual-reality', 'full-immersion', 'capital-markets', 'pan-recognition', 'relay-based', 'molecule-scale', 'pen-on', 'two-thirds', 'information-related', '2020-circa', 'information-processing', 'three-dimensional', 'Nano-engineered', 'super-computing', 'technology-creating', 'cell-sized', 'age-old', 'sub-optimal', 'nano-bots', 'nano-technology', 'self-organizing'}
# 45 {'four-year', 'part-time'}
# 46 {'dah-da', 'un-PC', 'U-turn', 'for-Christmas', 'ginger-snaps', 'hot-shit', 'gruff-ex', 'hot-shot', 'da-la', 'modern-day', 'spit-bath', 'ooh-eee', 'la-dat', 'still-sends', 'da-dah', 'kind-of', 'ditzy-but', 'cop-on', 'his-fourth'}
# 47 {'two-thirds', 'the-art', 'low-tech', 'low-cost', 'high-tech', 'state-of'}
# 48 {'self-doubts', 'micro-computer', 'two-hour', 'self-doubt'}
# 49 {'multi-story', 'sub-municipality', 'Mercedes-Benz', 'right-hand', 'eating-place', 'over-arching', 'stick-and', 'self-built', 'mud-hut', 'pit-latrine', 'trash-disposal'}
# 50 {'not-number', 'family-size', 'individual-size'}
# 51 {'nation-state', 'old-growth', 'nine-year', 'well-being', 'two-dimensional', 'sub-Saharan', 'beta-carbolines', 'self-consciously', '5-methoxydimethyltryptamine'}
# 52 {'non-violent', 'cross-cultural', '69-year', 'one-third', 'high-speed', 'wallet-sized', 'beat-up', '62-year', 'non-violence', 'curare-tipped'}
# 53 {'super-eruptions', 'post-World', 'human-induced', 't-shirt', 'large-scale', 'post-human', 'two-dimensional', 'fine-grained', 'one-millionth', 'Bio- and', 'billion-year', 'light-years', 'post-War', 'micro-world', 'self-effacing', 'high-dimensional', 'time-lapse', 'three-dimensional', 'so-called', 'latter-day', '21st-century'}
# 54 {'non-zero', 'multi-village', 'self-interest', 'win-lose', 'op-ed', 'zero-sum', 'zero-zero', 'counter-measures', 'long-term', 'one-celled', 'hunter-gatherer', 'trans-Atlantic', 'business-class', 'self-interests', 'Non-zero', 'win-win', 'half-joking', 'lose-lose', 'high-level', 'so-called', 'city-state', 'long-standing'}
# 55 {'op-ed', 'pro-am', 'consumer-driven', 'open-source', 'kite-surfing', 'clear-cut', 'pro-ams', 'table-football', 'in-built', 'co-developers', 'co-producers'}
# 56 {'stand-up', 'five-month', 'mid-1850s', 'public-health', 'one-room', 'multi-disciplinarian', 'higher-level', 'large-scale'}
# 57 {'op-ed', 'Young-Soon', 'African-Americans', 'Korean-Americans', 'rear-view', 'non-violence', 'I-95'}
# 58 {'self-replicating', '000-square', 'micro-controller', 'three-dimensional', 'self-replication', 'if-then', 'two-bit', 'self-assembly', 'two-dimensional', 'five-state', 'chocolate-dipping', 'hands-free', 'sub-routine'}
# 59 {'mega-projects', 'inter-network', 'top-down', 'the-art', 'press-fit', 'bottom-up', 'hands-on', 'inter-networking', 'micro-machining', 'Secondi-Takoradi', 'on-demand', 'de-multiplexing', 'high-gain', 'high-speed', 'self-replication', 'high-tech', 'numerically-controlled', '10-billion', '100-nanosecond', 'Wal-Mart', 'state-of', 'quantum-mechanically', 'fan-out', 'inner-city', 'micro-finance', 'eight-year'}
# 60 {'35-hour', 'bite-size', 'speed-aholic', 'blue-chip', 'micro-company', 'full-throttle', 'high-achieving', 'One-Minute', 'fee-paying', 'time-starved', 'a-half', 'rush-aholic', 'wake-up', 'mid- 80s', 'to-do', 'kick-ass', 'fast-forward', 'three-and', 'quick-fix'}
# 61 {'anti-Sandinista', 'Palestinian-Israeli', 'counter-tactic', 'house-to', 'decision-making', 'out-of', 'anti-war'}
# 62 {'disease-causing', 'one-third', 'quasi-organisms', '10-to', 'Human-forced', 'mind-boggling', 'the-18th', 'one-celled', 'over-harvesting'}
# 63 {'three- to', 'e-venture', 'non-governmental', 'uncertain-payment', 'one-dollar', 'industry-right', 'four-tenths', '10-year', 'certain-payment', 'per-capita', 'world-class', 'low-volume', 'a-half', 'high-volume', 'high-margin', 'two-and', 'non-democratic', 'full-time', 'less-than', 'well-deserved', 'second-line', 'five- to', 'high-quality', 'low-margin', 'three-tenths', 'a-day', 'four-hundred'}
# 64 {'vapor-compression', 'multi-billion', '150-pound', 'high-speed', 'long-range', 'watt-hours', 'techno-geeks', 'half-hour', 'nickel-metal', 'green-space', 'nickel-cadmium', '30-minute', 're-energize', 'un-park', 'high-volume', 'counter-flow', '100-year', '120-volt', '000-pound', 're-condense', 'large-weight', 're-park'}
# 65 {'spring-loaded', '100-pound', 'high-speed', '300-pound', 'self-destruct', 'X-axis', 'well-established', 'Y-axis', 'saddle-shaped'}
# 66 {'co-mentor', 'ex-house', 'people-work', 'half-a', 'super-waldo', 'brute-iful', 'self-moving', 'car-y', 'stressed-out'}
# 67 {'cheek-flapping'}
# 68 {'20-letter', 'three-stranded', 'nature-nurture', 'left-handed', 'turned-crystallographer', 'high-intelligence', 'right-handed', 'sub-segment', 'x-ray', 'four-letter', 'electro-model', 'digital-type', 'X-ray', 'strand-separating'}
# 69 {'Band-Aided', 'Llewelyn-Bowen', 'gadget-lustish', 're-framing', 'staring-at', 'death-by', 'four-inch', 'hard-core', 'two-handed', 'thumb-scroll', 'in-the', 'you-right', 'rear-view', 'co-opt'}
# 70 {'sub-categories', 'two-thirds', 'sub-space', 'well-being', 'anti-depressants', 'self-control', 'long-term'}
# 71 {'13th-century', 'un-representable'}
# 72 {'Harvard-educated', 'HER-2', 'uh-uh', 'over-expresses', '000-dollar', 'species-mapping'}
# 73 {'self-assemble', 'self-cleaning', 'build-up', 'stop-protein', 'self-assembles', 'hydrogen-juggling', 'energy-harvesting', 'human-made', 'self-assembly', 'high-tech', 'self-assembling', 'plant-like', 'distortion-free', 'bio-assisted', 'up-close', 'field-testing', '10-second', 'thin-film', 'low-temperature', 'bio-mineralization', 'well-adapted', 'bio-silicon', 'collision-avoidance'}
# 74 {'co-op', 'Co-evolution', 'single-celled'}
# 75 {'never-ending'}
# 76 {'Pixar-type', 'un-retouched'}
# 77 {'fun-filled', 'bi-species', 'hard-wired', 'a-half', 'well-kept', 'high-pitched', 'two-and', 'long-distance', 'Slim-bodied', 'human-like', 'Savage-Rumbaugh'}
# 78 {'tried-and', 'worst-case', 'time-frame', 'all-natural', 'hydrogen-generating', 're-identifying', 'fog-catcher', 're-categorizing', 'quarter-million', 'car-share', 'neo-biological', 'Asia-Pacific', 'high-speed', 're-label', 'landmine-detecting', 'crib-note', '60-second', 'non-violent', 'half-billion', 'bio-morphic', 'bio-mimicry', 'low-cost', 'merry-go', 'jungle-like', 'hacked-together', 'north-south', 'anti-globalization'}
# 79 {'two-week', 'oxygen-insensitive', '000-base', 'genome-centric', 'bio-terrorism', 'free-living', 'T-shirts', 'cassette-based', 'single-cell', 'multi-institutional', 'know-how', 'non-essential', 'a-half', 'ten-thousandth', 'gene-centric', 'so-called', 'right-hand', 'year-and', 'one-thousandth'}
# 80 {'low-tech', 'pre-Columbian', 'brand-new', 'age-old', 'three-point', 'un-graspable', 'non-specific'}
# 81 {'55-foot', 'wood-fired', 'three-star', 'Fastest-growing', 'best-selling', 'TV-industrial', 'pooh-pooh', 'military-industrial', '000-dollar', 'third-rate', 'second-rate', 'super-expensive', 'super-outrageous', 'two-hour', '40-foot', 'full-page'}
# 82 {'city-making', 'two-dimension', '19th-century', 'eight-acre', 'larger-scale', 'four-kilometer', 'north-south', 'three-dimension', 'non-sequiturs', 'performance-driven', 'short-term', 'large-scale'}
# 83 {'bush-meat', 'pre-school', '40-odd', 'tool-making', 'non-human', 'clear-cutting', 'tool-using', '60-plus', 'sun-dry', 'non-verbal', 'far-away', 'inner-city', 'sun-specks', 'long-term'}
# 85 {'lady-in', 'green-painters', 'sawing-the', 'from-the', 'change-blindness', 'thought-balloon', 'feature-length', 'whiter-than', 'filling-in', 'third-person', 'computer-animator', 'purple-painters', 'high-resolution', 'thought-bubble'}
# 86 {'Single-stroke', 'hand-stick', 'so-called', 'single-stroke', '90-degree', '15-year', 'full-time', 'organ-like'}
# 87 {'solar-heated', 'solar-powered', 'self-replicates', 'so-called', '350-pound', '24-hour', 'Wal-Mart', 'lowest-cost', 'mass-produced', 'five-minute'}
# 88 {'broke-ass', 'gold-plated', 'drop-top', 'man-in', 'late-night', 'got-a', 'ex-lover', 'the-street', 'Ah-Salam', 'boob-job'}
# 89 {'early-adopter', 'rinse-water', 'boom-bust', 'breaking-bones', 'kludge-y', 'long-distance', 'Sixty-eight', 'left-hand', 'fine-grained'}
# 92 {'warm-up', 'junior-high', 'Roll-Ups', 'best-selling', 'first-class', 'one-third', 'ucked-fay', 'roll-up', 'seven-dimensional', 'Aquecer-se', 'Prince-Ramus', 'cradle-to', 'Purpose-Driven'}
# 93 {'deep-down', 'non-existence', 'non-citizen', 'well-organized', 'way-out', 'anti-Templeton', 'non-linearities', 'pre-version', 'non-explanations', 'poverty-stricken', 'K-T', 'tooth-fairy', 'a-fairyists', 'Non-theist', 'socio-economic', 'consciousness-raising', 'coming-out', 'non-professional', 'non-religious', 'vote-seeking', 'coming-in', 'so-called', 'non-theist', 'meta-analysis', 'non-confrontational', 'step-by', 'a-teapotists'}
# 95 {'semi-detached', 'in-dwelling', 'puppet-master', 'mile-per', 'in-ness', 're-statement', 'pre-school', 'three-way'}
# 96 {'no-names', 'non-innovative', '30-dollar', 'technology-trigger', 'home-theater', 'number-one', 'video-rental', 'Wi-Fi', 'anti-retrovirals', 'Wal-Mart', 'pissed-off', 'top-10', 'Law-like', 'high-quality', 'stock-market', 'surround-sound', 'big-screen', 'price-line', 'out-sold', 'sub-Saharan', 'e-commerce', 'lead-time', 'mid-1990s', 'drive-by', 'anti-retroviral', 'no-name'}
# 97 {'A-ha', 'search-wise', 'high-school', 'self-serve', 'full-blown', 're-imported', 'well-organized'}
# 99 {'non-articulated', 'retro-fitted', 'down-scale', '000-year', 'R2-D2', 're-scale', 'Wal-Mart', 're-learn', 'mid-21st', 'Band-Aid', 'mid-19th', 'retro-fitting', 'C-3PO', 'Wal-Marts', 'hyper-car', 'Band-Aids', 're-size'}
# 100 {'video-feed', 'wide-open', 'non-profit', 'human-centered', 'minute-and', 'deep-well', '3-D', 'off-season', 'man-machine', 'a-half', 'one-way', 'low-cost', 'battery-powered', 'video-production', 'seed-squeezers', 'hay-balers', 'low-budget', 'human-centeredness', 'built-in'}
# 101 {'home-brewed', 'One-sixth'}
# 102 {'non-intelligent', 'high-dimensional', 'Zen-like', 'traffic-light', 'pre-paradigm', 'single-topic', 'non-mammal', 'real-live', 'real-world', 'C-3PO', 'script-writing', 'auto-associatively'}
# 103 {'four-foot', 'cut-off', 'three-dimensional', 'Kipling-esque', 'low-energy', 'pre-programmed', 'evolutionarily-derived', 'by-the', 'by-catch', 'nine-course'}
# 104 {'behind-the', 'sixth-largest', 'second-largest', 'six-trillion', 'Wal-Mart', 'flex-fuel', 'pay-off', '15-year', 'market-based'}
# 105 {'cross-modal', 'multi-resolution', 'data-sets', 'T-shirts', 'pop-ups', 'multi-scale', 'slide-show', 'by-product', 'e-book', 'computer-vision', 'meta-data', 'cross-user', 'meta-verse', 'co-advised', 'non-image', 'cell-phone'}
# 106 {'two-thirds', 'second-fastest', 'macro-economy', 'Wal-Mart', '30-year', 'sub-Saharan', 'multi-party', 'oil-rich', 'slip-ups', 'de-linked', 'non-oil', 'revenue-earning', 'world-class'}
# 107 {'cave-painting', 'post-it', 'double-click'}
# 108 {'movie-star', 'self-centered', 'have-nots'}
# 109 {'de-mountable', 'window-washing', 'post-September', '16-acre', 'go-ahead', 'anti-graffiti', 'number-one', 're-look', 'step-daughter', 'long-term', 'Atlantic-Heydt', 're-opening', 'barn-raising', 'ad-hoc'}
# 110 {'inter-agency', 'non-zero', 'day-to', 'self-discovery', 'non-governmental', 'anti-access', 'Trigger-pullers', 'non-lethal', 'long-range', 'agency-ize', 'long-term', 'straight-up', 'first-half', 'follow-on', 'area-denial', 'trigger-pullers', 'self-actualization', 'Jong-Il', '40-year', 'trigger-happy', '19-year', 'Al-Sadr'}
# 111 {'geo-registering', '3-D', 'geo-positioning', 'ortho-view', 'brand-new', 'like-type', 'nadir-view', 'multi-spectral'}
# 112 {'pre-Medieval', '100-year', 'great-grandma', 'grandma-verified', 'farmers-needs', 'off-road', 'public-health', 'micro-credit', 'great-great', 'sub-Saharan', 'non-governmental', 'Carbon-dioxide', 'Micro-credits', 'Tse-Tung', 'one-fifth', 'high-income', 'grand-daughter'}
# 113 {'jump-starting', 'nuclear-heated', 'paradigm-buster', 'three-dimensional', 'robotically-discovered', 'all-seeing', 'science-fiction', 'life-support', 'two-year', 'earth-to', 'sensor-lock', 'closed-cycle', 'low-earth', 'inter-personal', 'extra-vehicular', 'little-known'}
# 114 {'Shaker-dom', 'the-box', 'self-interest', 'all-terrain', 'out-of', 'full-time'}
# 115 {'tissue-specific', 'cell-based', 're-growing', 'fat-derived', 'early-onset', 'inter-disciplinary', 'tissue-engineering', 'year-old', 'bio-degradable', 'wound-healing', 'back-flush', 'adipose-derived', 'bio-reactor', 're-attached', 'tummy-tuck', 'eight-institution', 'stem-cell', 're-grow', 'bio-reactors'}
# 116 {'seven-and', 'open-ended', 'a-half', 'newly-posted', 'self-expression', '35-watt'}
# 117 {'inter-connectedness', 'pre-emptive', 'mortality-based', 'extra-marital', 'sub-Saharan', 'high-risk', 'long-term', 'well-educated', 'pre-marital'}
# 118 {'a-cryin', 'green-haired', 'so-called', 'self-inflicted', 'wrap-up'}
# 119 {'20-year', '240-dollar', 'God-like', 'single-cell', 'failure-based', 'world-renowned', 'two-dimensionally', 'high-leverage', 'self-conscious', '15-year', 'long-term', 'eight-year', 'short-term'}
# 120 {'micro-machines', 'awe-full', 'three-minute', 'self-directed'}
# 121 {'un-Canadian', 'X-rays', '18-month', '70-year', '89-year'}
# 122 {'begging-bowl', 'boat-building', 'heads-of', 'Swiss-bank', 'post-colonial', 'head-of', 'free-market'}
# 124 {'re-hydration', 'Nigeria-Biafra', 'fastest-growing'}
# 125 {'vis-a', 'small-scale', 'A-plus', 'public-sector', 'call-centers', 'second-largest', 'Singaporean-based', 'B-minus', 'long-term', 'macro-factors', 'B-plus', 'democratically-elected', 'pan-African', 'cross-flow', 'double-digit', 'no-go', 'middle-class', 'million-plus', '24-hour', 'hydro-electric'}
# 126 {'upper-middle', 'student-crafted', 'AK-47', 'C-section', 'sub-Saharan', 'life-altering', 'pre-mid'}
# 127 {'middle-class', 'Biafran-Nigerian', 'self-loathing', 'Neo-Nazis', 'Ka-doooom', 't-shirt', 'Njoku-Obi'}
# 128 {'public-private', 'for-profit', 'hitting-it', 'R-E', 'world-quality', 'best-known', 'long-term', 're-dipped', 'E-C', 'polyethylene-based', 'non-African', 'S-P', 'Bio-Extracts', 'self-sufficient', '20-million', '40-year', 'the-box', 'A-Team', 'old-hand', 'value-add', 'out-of', 'well-intentioned'}
# 130 {'true-life', 'well-traveled', 'non-controversial', 'straight-to', 'Mid-East', 'long-term', 'wake-up', 'full-time', 'pro-social'}
# 131 {'some-odd', '30-second'}
# 132 {'un-dictionaried', 'F-word', 'T-E', 'S-C', 'D-I', 'non-perks', 'book-shaped', 'eight-track', 'little-known', 'R-E', 'word-collecting', 'higgledy-piggledy', 'left-hand', 'ball-peen'}
# 133 {'Hand-to', 'four-wheel', 'thirty-three', 'well-paying', 'thirty-four', 'semi-autonomous', 'policy-making', 'duty-free', 'wealth-creating', 'policy- implementation', 'self-interest', 'self-initiative', '2006-2007', 'policy-orientation', 'sub-counties', 'hangers-on', 'poverty-stricken'}
# 134 {'in-between'}
# 135 {'figure-ground', 'a-recipient', 'double-object', 'quasi-metaphorical', 'game-theoretic', 'first-name', 'if-then', '50-dollar', '000-dollar', 'recipient-thing', 'knowledge-intensive', 'subject-verb', 'thing-to', 'fine-grained'}
# 136 {'post-World', 'one-on', 'non-governmental', 'left-hand', 'op-ed', 'positive-sum', 'non-existent', 'non-violence', 'non-violent', 'nonzero-sum', '15-year', 'labor-saving', 'so-called', 'sixteenth-century', 'twenty-first', 'Hunter-gatherer', 'mini-van', 'sub-human', 'hunter-gatherers'}
# 137 {'one-six', 'one-four', 'a-lifetime', 'once-in', 'Wide-awake'}
# 138 {'three-year', 'still-growing', 'day-to', 'small-brained', 'pre-frontal', 'close-up', 'chimp-like', 'chimpanzee-like'}
# 139 {'Abdul-Jabbar', 'butter-fry', 'time-graphics', 'french-fry', 'twenty-four', 'One-piece', 'eighty-year', 'fall-based', 'mid-thirties', 'over-achiever', 'ninety-six', 'self-drawing', 'seventy-four', 'ninety-year', 'butter-fries'}
# 140 {'Earth-like', 'no-take', 'asteroid-slash', 'flat-footed', 'three-dimensional', '10-dollar', 'high-speed', 'heavy-duty', 'space-faring', 'high-energy', 'sober-minded', '200-foot', '22-mile', 'pump-push', 'super-flares', 'outward-looking', 'two-trillion'}
# 141 {'solar-powered', 'cutting-edge', 'one-mile', '000-pound', 'Gossamer-Condor', 'SR-71', '000-dollar', 'on-board', 'high-resolution', 'self-land', 'human-powered', 'Battery-powered'}
# 142 {'Earth-like', 'in-depth', 'edge-on', 'blue-ocean', 'color-code', 'low-lying', 'European-built'}
# 143 {'Post-Napster', 'get-go', 'Coca-Cola', 'car-boat', 'twenty-fifth', 'self-sustaining', 'know-how'}
# 144 {'self-models', 'self-replicate', 'self-replication', 'micro-scale', 'self-model', 'x-ray'}
# 145 {'op-ed', 'look-alike', 'lie-down', 'dry-cleaning', 'murder-mystery', 'wonderful-looking', 'Gell-Mann', 'full-time', 'simple-minded'}
# 146 {'e-mail', 'never-ending', 'street-up', 'reverse-engineer', 'out-of', 'micro-lending'}
# 147 {'so-called', 'number-color', 'Ninety-nine', 'cross-model', 'tone-color', 'three-pound', 'self-awareness', 'cross-connected', 'across-the', 'ki-ki'}
# 148 {'profit-minded', 'cookie-cutter', 'in-house', 'back-to', 'pan-African', 'under-capitalized', 'low-cost', 'mind-boggling', 'Well-functioning'}
# 149 {'well-known', 'so-called', 'fast-forward', 'near-disaster', 'two-tenths', '39-year', 'long-term', 'full-time', '43-year'}
# 150 {'super-modern', 'non-stop', 'Coca-Cola', 'well-being', 'the -0', 'high-tech', 'self-perpetuating'}
# 151 {'top-down', 're-creation', 'non-commercial', 'user-generated', '100-years', 'read-write', 'amateur-type', 're-edited', 'read-only', 'more-free', 'less-free', 'User-generated'}
# 152 {'e-mail', 'high-level', 'three-dimensional', '30-atom', 'amino-acid', 'self-assembly', '130-nanometer'}
# 153 {'mid- 90s', 'uh-uh', 'Geo-engineering', 'geo-engineering', 'bomb-like', 'un-PC', 'geo-engineered', '43-or', 'non-geo'}
# 154 {'two-thirds', 'well-known', 'one-to', 'doo-doo', 'coal-fired', 'non-revenue', 'eight-fold', 'large-scale', 'geo-spatial'}
# 155 {'20-20', 'Sub-Saharan', 'human-rights', 'coal-fired', 'glass-bottomed', 'low-lying', 'far-reaching', 'self-interest', 'weather-related', 'zoonotic-borne'}
# 156 {'curiosity-based', '20-fold', 'self-cleaning', 'leaf-like', 'two-phase', '200-nanometer', 'foot-bot', 'shrimp-like', 'shape-deposition', 'six-legged', 'Band-Aid', 't-shirt', 'search-and', 'bio-inspired'}
# 157 {'self-replicating', 'self-similarity', 'Ba-ila', 'log-log', 'self-organization', 'bottom-up', 'age-grade', 'pseudo-random', 'African-American', 'Self-organization', 'cost-benefit', 'self-generating', 'four-bit', 'self-similar', 'self-organizing'}
# 158 {'pshoo-shoo', 'Mu-ta', 'super-monkey', 'bloop-bloop'}
# 159 {'self-similarity', 'funny-looking'}
# 160 {'wally-badged', 'carbon-fiber', 'eight-year', 'bio-fuels', 'five-sixths', 'blended-wing', 'three-fourths', 'leap-frog', 'quintupled-efficiency', 'suburban-assault', 'auto-making', 'oil-illuminating', 't-boned', 'light-handed', 'production-costed', 'trans-ideological', 'fee-bates', 'co-sponsored', 'seven-eighths', 'two-seater', 'billion-dollar', 'peer-reviewed', 'a-year', 'bio-diesel', 'ultra-light', 'bio-fuel', 'high-volume', 'life-cycle', 'million-car', 'low-cost', 'profit-maximizing', 'four-seater', 'Far-off', 'tier-one', 'nega-barrels', 'grand-kids', 'low-income', 'materials-industrial', 'ag-value', 'super-efficient', 'no-brainer', 'African-American', 'semi-conductor', 'supply-side', 'two-fifths', 'Prize-style', 'carbon-composite'}
# 161 {'seven-digit', 'Eight-digit', 'four-digit', '10-digit', 'two-digit', 'three-digit', 'five-digit', 'six-digit'}
# 162 {'brother-in', 'non-virtuous', 'Wi-Fi', 'non-stop', 'co-eds', 'self-focus', 't-shirt', 'matter-of', 'self-absorption'}
# 163 {'soul-searching'}
# 164 {'whole-body', 'open-pit', 'target-based', 'second-graders', 'Two-parter'}
# 165 {'flag-bearers', 'two-thirds', 'so-called', 'trickle-down', 'three-week'}
# 166 {'well-groomed', 'Wi-Fi', 'hair-free'}
# 167 {'seed-eating', 'three-year', 'five-year', 'colony-specific', 'three-color', 'two-year', 'pair-wise', 'task-specific', 'adobe-like', 'one-year'}
# 168 {'silk-screening', '10-year', 'ground-breaking', 'action-adventure', 'mind-blowingly', 'divorce-crippled', 'two-hour', 'pop-up'}
# 169 {'pitch-black', 'head-foots'}
# 170 {'three-year', 'salt-and', 'open-source', 'museum-quality', 'great-grandfather', 'de-mining', 'hands-on', 'half-full', 'low-cost', 'intra-toe', 'half-empty', 'water-sterilizing', 'Akzidenz-Grotesk', 'hammer-on', 'wide-ranging', 'sans-serif'}
# 171 {'well-intentioned', 'Yo-Yo'}
# 172 {'made-up'}
# 173 {'ex-steel', 'black-run', 'Hewlett-Packard', 'African-American', 'blown-up', 'high-tech', 'Bayview-Hunters', 'left-hand', 'four-year', 'at-risk', 're-engineered'}
# 174 {'middle-aged', 'non-Indo', 'Austro-Hungarian', '20-by', 'Methodist-affiliated', 'double-knit', '90-year', '16th- and', '70-odd', 'present-day', '17th-century', 'open-heart', '20-foot'}
# 176 {'look-alike', 'Di-Dodian', 're-used', 'mixed-race', 'look-alikes', 'Coca-Cola', 'upside-down', 'spot-on', 'non-humorous', 'golf-clubbed', 'pre-Iraq'}
# 177 {'mind-blowing', 're-birth', 'self-worth', 'TED-like'}
# 178 {'fuel-efficient', 'Ad-hoc', 'open-source', 'single-purpose', 'over-consumed', 'mesh-network', 'road-tolling', 'coast-to', 'low-cost', 'peer-to', 'single-occupancy', 'mesh-enabled', 'lowest-cost', 'market-based', 'real-time', 'self-configuring'}
# 179 {'double-articulated', 'co-responsibility', 'one-minute', 'metro-nizing', 'multi-use', 'mother-in'}
# 180 {'three-dimensional', '26-foot', 'sun-drenched', 'left-hand', 'pop-up', 'Santos-Dumont'}
# 181 {'zero-sum', 'close-up', 'sativa-indica', 'co-evolutionary', 'self-serving', 'Mini-Me', 'self-importance', 'quarter-acre', 'root-shoot'}
# 182 {'slash-and', 'co-evolving', 'double-entry', 'self-organized', 'joint-stock', 'self-interest', 'all-important', 'world-class', 'peer-to', 'many-to'}
# 183 {'Whoo-hoo', 'sci-fi', 'hoo-hoo'}
# 184 {'20-kiloton', 'quarter-second', '1957-65', 'five-year', '20-man', 'high-explosive', 'contingency-plan', 'pulse-system', 'blow-up', 'ground-hazard', 'off-the', '000-ton', 'three-pound', '130-foot', 'five-kiloton', 'eight-man', 'bomb-propelled', 'sub-woofers'}
# 185 {'three-year', 'self-expression', 'counter-proposal'}
# 186 {'Gell-Mann', 'Soon-Yi', 'girlfriendy-ness'}
# 187 {'Seven-club', 'razor-sharp', 'mid-year', 'high-tech', 'panther-like', 'mid-air'}
# 188 {'40-50', 'cow-dung'}
# 189 {'2-stage', 'Woo-hoo', 'bunker-buster', 'cruise-missile', 'NASCAR-like', 'X-ray'}
# 190 {'six-year'}
# 191 {'non-obvious', 'non-simple', 'six-year', 'nine-year', 'first-grade', 'second-order', 'Gell-Mann', 'first-order'}
# 192 {'billion-plus', 'higher-value', 'petrol-chemical', 'self-replicate', 'second- and', '000-letter', 'fourth-generation', 'third-generation', '50-letter', 'six-second', 'four-letter', 'boiling-water'}
# 193 {'sound-sync', 'double-breasted', 'computer-readable', 'text-sync', 'High-tech', 'three-year', '19-inch', 'pressure-sensitive', 'one-and', 'a-half', 'high-resolution', 'high-touch', 'ping-pong', 'pre-processed', 'touch-sensitive', 'encyclopedia-style', 'two-headed', 'one-finger', 'well-formed', '13-inch', 'low-resolution', 'step-by'}
# 194 {'full-body', 'inner-peace', 'three-inch', 'energy-being', 'energy-beings', 'life-force', 'full-exercise', 'weird-looking'}
# 195 {'three-piece', '19th-century', 'high-rise', 'non-fire', 'frog-like', 'fast-food', 'Morandi-like', 'Fin-Ply', 'Ritz-Carlton', '10-story', 're-proportioned', 'high-tech', 'up-the', 'po-mo', 'left-hand', 'sub-divided', 'C-clamp'}
# 196 {'computer-next', 'cross-pollination', 'one-on', 'self-expression', 'dot-com', 'Center-for', 'non-profit', 'English-Related', 'crime-fighting', 'supply-like', 'pro-bono', 'under-funded', 'Need-More', 'Super-Has', 'steel-graded', 'to-computer', 'Straight-Up', '7-Eleven', 'Kids-That', 'hard-working', 'full-time', 'would-be', 'shoulder-to', 'one-to', 'co-wrote', 'Writing-Related'}
# 197 {'old-fashioned', '10-year', 'co-religionists', 'self-indulgent', 'human-heartedness'}
# 198 {'e-mail', 'high-level', 'three-dimensional', '24-hour', 'three-month', 'pan-African', 'high-energy', 'problem-solving', 'pre-existing', 'cost-effective', '80-room'}
# 199 {'mega-cities', 'hand-cut', 'energy-conscious', 'mega-building', 'large-scale', 'Bucky-inspired', '30-odd', 'carbon-free', 'future-proofed', 'high-performance', 'geo-political', 'one-tenth', 'un-built', 'pollution-free', 'Asian-Pacific', '60-year', 'mid- 50s', 'three-dimensional', 'fast-forward'}
# 200 {'non-invasively'}
# 201 {'on-screen', 'open-to', 'eighth-grade', 'broad-mindedness', 'all-the', 'odd-problem', 'non-orientable', 'one-sided', 'Hewlett-Packard', 'three-quarters', 'college-level', 'and-do', 'chapter-seven', 'bell-tower', 'ten-foot', 'non-gray'}
# 202 {'well-developed', 'well-known', 'three-quarters', 'self-portrait', 'self-portraits'}
# 203 {'man-made'}
# 204 {'Mama-san'}
# 205 {'long-term', 'inward-looking', '10-billion'}
# 206 {'Sixty-nine', 'moderate-to', 'high-voltage', 'so-called', 'sub-prime', 'low-carbon', 'man-made', 'coal-fired', 'Sixty-eight', 'all-important', 'forward-leaning', 'Twenty-eight'}
# 207 {'game-development', 'multi-touch', 'high-performing', 'motion-sensing'}
# 208 {'long-term', 'Yo-Yo', 'high-packed', 'hyper-cello'}
# 209 {'property-based', 'well-behaved', 'Wi-Fi', 'long-term', 'self-expression', 'floating-point', 'mass-circulation', 'e-commerce', 'Web-based', 'non-profits', 'fully-trained', 'Peer-to', 'market-based', 'non-market'}
# 210 {'in-house', 'Post-9', 'high-quality', '2008-09', 'non-communicable', 'multi-modality', 'health-care', 'self-confessed', 'cost-effective', 'self-care'}
# 211 {'non-tourist', 'about-ness', '18-minute', 'near-death', 'one-on', 'muse-like'}
# 212 {'cutting-edge', 'head-on', 'curled-up', 'easy-to', 'full-frame', 'counter-clockwise', 'ultra-microscopic', 'Calabi-Yau', 'one-dimensional'}
# 213 {'in-ear'}
# 214 {'re-create', 'T-shirt', 'super-symmetric', 'mini-Big', 'super-force', 're-collapsed', 'super-symmetry', 'standard-size'}
# 215 {'geo-sensitive', '10-hour', '20-odd', 'under-developed', 'software-training', 'human-centric', 'end-to', 'elementary-school'}
# 216 {'YouTube-like', 'multi-directional', 'near-permanent', 'old-growth', 'super-kingdom', 'micro-cavities', 'Uh-Oh', 'non-sporulating', 'space-conservative', 'carbon-hydrogen'}
# 217 {'anti-malarial', 'person-food', 'vector-borne', 'predator-like', 'left-hand', 'Bosack-Kruger', 'mosquito-proof', 'Y-axis', 'long-term', 'well-being', 'non-vector', 'short-term', 's-eye', 'to-person', 'right-hand', 'food-then', 'person-to', 'sub-Saharan', 'mosquito-proofed'}
# 218 {'computer-oriented', 'high-speed', 'S-Curve', 'five-ball', 'three-dimensionally', 'hand-oriented'}
# 219 {'nine-tenths', 'hyper-adapted'}
# 220 {'J-School', 'e-content', 'one-person', 'mini-bureaus'}
# 221 {'steroid-filled', 'farm-raised', 'fat-phobic', 'oil-based', 'fend-for', 'beta-carotene', 'fast-food', 'Earth-friendly', 'low-carb', 'anti-atom', 'proto-feminist', 'home-cooked', 'value-added', 'Pop-Tart', 'second-highest', 'industry-obsessed', 'health- and', 'one-fifth', 'hyper-consumption', 'semi-vegetarian', 'five-fold', 'so-called', 'God-like', 'low-fat', 'store-bought', 'atmosphere-altering', 'So-called', 'anti-cattle', 'well-intentioned', 'forward-thinking'}
# 222 {'high-bandwidth', 'I-2', '16-minute', 'commercial-grade', 'blue-gold', 'mid-ocean', 'one-year'}
# 223 {'mom-and', 'high-sugar', 'three-dimensional', 'Wi-Fi', 'civic-type', 'partnership-type'}
# 224 {'four-bar', 'stand-in', 'wire-bending'}
# 225 {'multi-parameter', 'price-wise', '12-volt', 'on-site', 'open-heart', 'X-rays', 'Open-heart', 'size-wise', 'X-ray', '13-year'}
# 226 {'commodity-exporting', 'third-generation', 'post-War', 'self-interest', 'self-effacement', 'long-term', 'then-global'}
# 227 {'self-replicating', 'meme-fest', 'techno-memes', 'oxygen-breathing', 'eco-camp', 'warmth-requiring'}
# 228 {'Slip-Slidin', 'high-speed', 'Wi-Fi', '20-some', 'high-return', 'high-risk', 'non-avian', 'high-res', 'Nui-an'}
# 229 {'pan-Andean', '000-year', 'so-called', 'pre-Columbian', 'nine-year', 'well-being', 'grown-up', 'cross-legged', 'north-south', 'able-bodied', 'Reichel-Dolmatoff', 'proto-shamanism'}
# 230 {'Gell-Mann', 'long-distance'}
# 231 {'one-third', 'well-being', '42-story', 'anti-anxiety', 'neo-Gothic', 'One-third'}
# 232 {'Twenty-four', 'multi-cellular', 'g-Beam', 'tar-like', 'jump-started', '000-byte', 'V-40', 'viral-geneticist', 'data-processing', 'V-belts', 'self-reproducing', 'soldering-gun', 'one-year'}
# 233 {'disease-preventing', 'disease-promoting', 'anti-smoking'}
# 234 {'self-cleaning', 'self-stabilizing', 'six- and', 'Mecho-Gecko', 'self-stabilizes', 'small-size', 'eight-legged', 'just-good', 'Mecho-Geckos', 'pressure-sensitive', 'forty-four', 'bio-mimicry', 'see-through', 'six-legged', 'Velcro-like', 'spring-mass', 'nano-size', 'six-millimeter', 'legged-robots'}
# 235 {'low-pressure', '15-liter'}
# 236 {'hard-to', 'three-year', 'zero-year', 'lap-only', 'two- to', 'six-year', 'rear-impact', 'bright-line', 'above-average', 'two-year', 'frontal-impact', 'dollar-a', 'lap-and', 'real-world', 'cost-effective', '300-million', 'open-minded', 'one-year'}
# 237 {'F-sharp', 'two-buttock', 'nine-year', '11-year', 'seven-year', '10-year', 'life-changing', 'on-the', 'one-buttock', 'second-hand', 'tone-deaf', '12-year'}
# 238 {'power-generating', 'pencil-yellow', 'laptop-land', 'sunlight-readable', 'mesh-network', 'pin-striped', 'Dual-mode', '24-hours', 'low-power', 'large-scale', 'off-board'}
# 240 {'zero-g', 'ever-increasing', 'world-renowned', 'wheelchair-bound', '65-year'}
# 241 {'60-year', '11-year', 'three-day', 'Eun-Sook', 'myth-buster', '15-story'}
# 243 {'40-hectare', 'Colombo-Tantalite', 'Al-Qaeda', 'hard-working', 'Jean-Pierre'}
# 244 {'two-legged', 'counter-balance', 'half-evolved'}
# 245 {'big-time', '40-some', '16-millimeter'}
# 246 {'no-carrot', 'roller-skating', 'truth-tellers', 'one-button', 'dual-income', 'photo-sharing', 'left-weighted', 'below-average', 'small-scale', 'well-enough', 'point-to', 'left-hand', 'purpose-built', 'de-professionalized', 'Kubler-Ross', 're-engineer', 'by-product', 'stay-at', 'Armstrong-style', 'self-preservation', 'pro-ana', 'run-down', 'institution-as', 'non-state', 'power-law', 'one-nth', 'hard-to', 'open-source', 'five-year', 'Pro-ana', 'no-stick', '13-year', 'real-world', 'Stay-at'}
# 248 {'take-it', 'do-it', 'kelp-like'}
# 249 {'face-to', 'city-state', 'eighth-century', 'long-term', 'side-by'}
# 250 {'self-hatreds', 'self-destructive', 'well-known', 'ad-libbing', 'seventeenth-century', 'face-to', 'present-day', 'age-old', 'self-delusion', 'self-destruct', 'eye-opening'}
# 251 {'poly-cotton', 'T-shirts', 'mid-70s', 'twenty-first', 'life-changing', 'Bible-talk', 'take-aways', 'Know-It', 'twenty-third', 'hip-hop'}
# 252 {'mind-control', '75-year', 'mind-reading', 'nine-millimeter', 'non-verbal', 'freak-ass', 'Mm-hmm'}
# 253 {'happy-ology', 'random-assignment', 'high-talent', 'placebo-controlled', 're-craft', 're-crafted', '300-word', 'Re-crafting', 're-crafting', 'long-term', 'media-train', 'smiley-ness'}
# 254 {'hard-to', 'mass-produced', 'come-by', 'higher-end'}
# 255 {'hungry-looking', 'X-Men', 'seven-year', 'six-inch', 'five-foot', '14-year'}
# 256 {'shortest-lived', 'fully-fledged', 'big-brained', 'upright-walking', '1-million', 'year-old', 'labor-intensive', 'super-intelligent', 'time-consuming', 'dark-skinned', 'slender-snouted'}
# 257 {'English-speaking', 're-inflated', '28-year', 'sub-stories', 'small-scale', '000-foot', '75-year', '26-year', 'cut-off', '10-year', '37-year', 'year-old', '24-year', '17-year', '21-year', 'non-materialistic', 'man-made', '16-year', '53-year', 'one-lane', 'black-and', 'five-minute', 'drop-offs', 'two-lane', 'high-level', 'good-natured', '11-year', '81-year', 'twenty-two'}
# 258 {'normal-shaped', 'metal-halide', 'non-orthogonal', '20-year', 'high-school', 'York-based', '16-story', 'Child-prodigy', 'brand-new', 'wine-buying', 'cad-cam', 'self-lit', 'off-site', 'small-scale', 'computer-operated', 'built-in', 'large-scale', 'dune-scape'}
# 259 {'Web-ness', 'wild-eyed', 'machine-readable', 'three-letter', 'take-away'}
# 260 {'odd-numbered', 'white-tailed', 'origami-on', 'airbag-flattening', '100-meter', 'two-colorability', 'quarter-circle', 'blow-up', 'even-numbered', 'quarter-mile', 'five-meter', 'sheet-like'}
# 262 {'five-string'}
# 263 {'ground-based', 'three-dimensional', 'twenty-first', 'well-motivated', 'space-based', 'non-interacting', 'non-interactive'}
# 264 {'sub-questions', 'sub-species', 'post-conference', 'at -70', 'super-highway', 'paleo-climatological', 'Y-chromosome', 'sub-group', 'co-produced', 'post-Darwinian', 'pre-Darwinian', 'even -100', 'grant-giving', 'take-home', 'well-intentioned'}
# 265 {'cross-sample', 'human-wildlife', 'pre-war', 'never-before', 'high-tech', 'old-school', 'straight-up'}
# 266 {'five-handed', 'Right-molded', 'high-frequency'}
# 267 {'low-frequency', 'dog-friendly', 'lower-frequency', 'hunky-dory', 'Mickey-Mouse', 'high-ranking', 'life-mate', 'brother-in', 'tummy-rub', 'down-stay', 'puppy-training', 'rolled-up', 'face-to', 'low-ranking', 'search-and', 'life-or', 'high-frequency', 'puppy-train', 'Laytay-chai', 'all-time', 'time-sample'}
# 269 {'high-definition', 'Ninety-nine', 're-mastering', 'high-resolution', 'step-by'}
# 270 {'self-organization', 'day-to', 'over-hyped', 'self-organize', 'self-instruct', '12-year', 'Internet-based', 'six- to', 'counter-intuitive', 'under-performing', 'high-speed', 'self-organized', 'fault-tolerant', 'the-wall', 'values-oriented', 'socio-economic', 'six-year', 'hole-in', 'super-duper', '13-year', 'eight- and', 'eight-year', 'self-organizing'}
# 271 {'Harvard-educated', 'first-year', 'doctor-patient', 'non-native', 'long-term', 'poli-sci'}
# 272 {'never-ending', 'Cock-a', 'five-pound', 'modern-day', 'doodle-doo', 'wrap-up', 'good-looking'}
# 273 {'self-assemble', 'biomolecule-centric', 'atomic-force', 'cell-oriented', 'single-stranded', 'computer-fabricated', 'two-wing', 'self-assembly', 'self-assembling', 'one-tenth', 'nano-artwork', 'nano-circuits', 'six-fingered', 'nano-goatee', 'self-assembled', 'nano-tubes', 'high-level', 'three-dimensional', 'right-hand', 'four-wing', 'one-thousandth', 'computer-aided', 'double-stranded'}
# 274 {'7-Up', 'short-circuit', 'killer-sized', 'micro-power', 'Twenty-six', 'trillion-dollar', 'self-loading', 'industrial-military', 'hole-in', 'price-improvement', 'platinum-group', 'world-class'}
# 275 {'Berners-Lee', 'four-core', 'left-hand', 'real-time', 'user-generated', 'mini-computer', 'high-speed', 'A-Bomb', 'air-conditioning', 'lock-in', 'anti-war', 'Semi-Automatic', 'pre-made', 'diesel-driven', 'man-made', 'open-source', 'mid-peninsula', 'right-hand', 'mid- 50s', 'twenty-first', 'long-forgotten', 're-regulation'}
# 276 {'in-joke', 'three-dimensional', 'anti-American', 'seven-year', 'hands-on', 'torch-bulb', 'two-dimensional', 'British-like'}
# 277 {'Congo-Brazzaville', 'three-year', 'desert-like', '30-square', 'ex-child', 'tool-using', 'Saro-Wiwa', 'micro-credit', 'sub-Saharan', '30-foot', 'human-like', 'non-scientific', 'ape-like'}
# 278 {'Two-mile', 'hurricane-like', 'counter-launch', 'all-out', 're-commissioned', 'counter-proliferate', 'retaliation-proof', 'high-value', 'know-how', 'Nagasaki-size', 'nation-versus', 'rent-a', '100-metric', 're-target', 'half-mile', 'wind-up', 'twenty-first', '10-kiloton', 'battery-less'}
# 279 {'in-print', 'book-like', 'kiosk-y', 'longer-term', 'print-on', 'turn-y', 'high-quality', 'law-wise', 'auto-page', 'e-book', 'in-library', 'high-grade', 'out-of', 'one-up', 'long-playing', 'good-looking', 'large-scale'}
# 280 {'jelly-type', 'V-shaped', 'neatest-looking', 'five-billion', 'hydrogen-sulfide', 'three-dimensional', 'light-sensing', 'deep-sea', 'short-lived', 'X-wing', 'mid-ocean', 'micro-gravity', '000-mile'}
# 281 {'uh-huh', 'hmm-hmm', 'play-by', 'half-whisper', 'slack-jawed', 'quick-witted', 'white-knuckle', 'crone-ish', 'wah-wah', 'Fifty-five'}
# 282 {'strip-mines', 'go-to', 'sub-sonic', '6-7', 'Br-r'}
# 283 {'stain-resistant', 'time-appropriate', 'seven- and', '20-minute', 'hands-on', 'public-private', 'high-fructose', 'farm-to', 'insulin-dependent', 'upside-down', 'be-all', '29-cent', 'over-prescribed', '99-cent', '19-month', 'five-pound', 'school-aged', 'end-all', 'African-Americans', 'chock-full', 'non-nutrient', '40-minute', 'diet-related', 'eight-year'}
# 284 {'left-wing', 'In-group', 'two-channel', 'five-channel', 'face-to', 'Post-election', 'Built-in', 'five-foundation', 'self-righteousness', 'right-wing', 'independent-minded', 'two-foundation', 'in-group', 'open-minded', 'pro-social'}
# 285 {'T-shirts', 'inter-bended', 'V-Day', '800-seat', 'date-raped', 'AK-47s', 'hard-matter', '30-foot'}
# 286 {'15-second', 'so-and', 'venture-funded', 'sixth-grader', 'Zen-like', 'not-for', 'Self-confidence', 'one-on', 'per-unit', '30-second', 'long-titled', 'wrap-up', 'five-minute'}
# 287 {'200-year', 'half-life', 'great-grandparent', 'long-range', 'great-great', 'rule-based'}
# 288 {'middle-aged', 'excuse-ology', 'socio-centrically', 'Fifty-year', 'African-American', 'social-psychological', 'bad-barrel', 'De-individuation', 'low-level', 'inner-city', 'self-labeling', 'white-collar', '1-A'}
# 290 {'17-year', 'co-inventor', 'CD-ROM', 'spoon-shaped', 'thirty-cent', '40-person', '3-D', 'foam-core', 'Play-Doh', 'single-cell', 'hand-held', 'see-through', 'pseudo-code', 'flight-testing'}
# 291 {'80-odd', 'left-handers', 'deeply-held', 'super-similar', 'age-old', 'self-evident', 'post-modernism', '000-odd'}
# 292 {'top-down', 'three-year', 'special-ness', 'highest-scoring', 'how-to', 'three-dimensional', 'turn-taking', 'wall-following', 'lawn-mowing', 'ever-increasing', 'pre-linguistically', 'home-cleaning', 'human-like', 'grown-ups'}
# 293 {'double-page'}
# 294 {'re-concentrating', 'post-9', 'vote-getters', 'co-exist', 'short-term'}
# 295 {'80-foot', 'technology-free', 'high-performance', 'anti-spectacle', 'semi-artificial', 'over-saturation', 'high-pressure', 'three-dimensional', 'gutter-ball', 'build-up', 'non-for', 'three-month', 'half-inch', 'multi-purpose', 'small-scale', 'full-scale', 'special-effects'}
# 296 {'XDR-TB'}
# 297 {'multi-millionaire', 'mid-summer', 're-programming', 'well-designed', '16-bit', 'life-altering', 'nine-second'}
# 298 {'baseball-loving', 'anti-Vietnam', 'red-checked', 'two-hour', 'hard-scrabble'}
# 299 {'day-old', 'a-half', 'post-9', 'one-to', 'one-way', 'right-hand', 'two-way', 'two-and', 'first-mover', 'well-linked', 'decision-making', 'higher-level', 'self-organizing'}
# 301 {'Pati-Salam', 'high-dimensional', 'four-dimensional', 'space-time', 'spin-down', 'eight-dimensional', 'start-up', 'right-handed', 'two-dimensional', 'spin-up', 'six-dimensional', 'left-handed', 'Gell-Mann', 'full-time', 'left- and'}
# 302 {'go-back', 'Tele-presence', 'high-speed', 'in-vitro', 'Pac-Man', 'blown-glass', 'go-to', 'object-based', 'brand-new', 'mind-opening', '3D-print', 'Auger-Loizeau'}
# 303 {'alien-style', 'good-looking', 'Hewlett-Packard', 'self-interest', 'not-glamorous', 'make-up', 'Bourke-White', 'spread-spectrum'}
# ...
# 3797 {'full-blown', 'short-term', 'well-shielded', 'post-concussion'}
# 3798 {'six-year', 'long-term', 'memory-making', 'short-term'}
# 3799 {'high-energy', 'long-term', 'self-esteem', 'self-awareness'}
# 3800 {'nano-sized', 'high-speed', 'bit-patterned', 'read-back'}
# 3801 {'one-size', 'fits-all', 'twenty-year'}
# 3802 {'so-called', 'un-baffle', 'space-time'}
# 3803 {'re-enter', 'low-power', 'quadratic-time'}
# 3804 {'single-handedly', 'brood-raiding', 'reproduction-capable', 'easy-to', 'super-organism'}
# 3806 {'patent-holding', 'best-selling', 'Thirty-four', 'two-way', 'public-health', 'two-year', 'full-circle', 'time-limited', '21st-century', 'patent-reforming'}
# 3807 {'long-term', '3-D', 'anxiety-filled'}
# 3808 {'anti-inflammatories', '48-pack', 'X-Women', 'risk-benefit', 'anti-inflammatory'}
# 3809 {'enzyme-replacement', 'single-letter', '000-year', 'higher-order', 'cheese-making', 'plastic-degrading', 'non-petroleum'}
# 3810 {'thin-walled'}
# 3811 {'high-skilled', 'high-quality', 'year-round', 'on-site', 'fiber-optic', 'weather- or', 'three-dimensionally', 'resource-efficient', 'energy-intensive', 'Ride-sharing', 'higher-efficiency', 'large-scale', 'highest-yielding', 'climate-proof'}
# 3812 {'self-management', 'real-real', '83-year', 'so-called', 'brand-new', 'color-coded', '30-odd', 'Fast-forward', 'technology-based'}
# 3813 {'nation-state', 'mini-part', 'tax-free', 'second-largest', 'trade-offs', 'Western-educated'}
# 3814 {'day-to', 'photo-taking'}
# 3815 {'t-shirt', 'thread-like', 'long-lasting'}
# 3816 {'20-year', 'day-to', 'hard-won', 'Time-series', 'sea-level', 'long-term', 'toxin-producing'}
# 3817 {'life-threatening', 'graft-versus', 'rock-solid'}
# 3818 {'150-year', 'three-tier', 'Jew-hating'}
# 3819 {'jump-starting', 'paper-like', 'crop-eating', 'wide-range', 'egg-laying', 'full-time'}
# 3820 {'custom-tailored', 'cutting-edge', 'open-source', 'peptide-design', 'small-molecule'}
# 3821 {'cutting-edge', 'mind-blowing', 'low-cost', 'ninth-grade', 'eighth- and', 'eye-opening'}
# 3822 {'toilet-seat', 'old-fashioned', 'data-science', 'light-green', 'human-zero', '70-percent', 'high-end', 'Seventy-five', 'Human-zero', 'B-737'}
# 3824 {'at-risk', 'hand-washing'}
# 3826 {'hover-blocks', 'self-assemble', 'brute-force'}
# 3827 {'get-go', 'star-crossed', 'wherefore-art'}
# 3828 {'Faster-moving', 'reaction-causing', 'book-dropping', 're-collect', 'dance-date'}
# 3829 {'f-factors', 'N-sub', 'F-sub', 'R-star', 'f-sub', 'n-sub'}
# 3830 {'is - anybody', 'Romano - uh', 'it - the', 'mind - Avogadro'}
# 3831 {'18th-century'}
# 3832 {'all-female'}
# 3833 {'awe-inspiring', 'life-harboring', 'Extra-Terrestrial', 'life-friendly', 'energy-harvesting'}
# 3834 {'modern-day', 'full-length'}
# 3835 {'well-meaning', 'self-actualized', '20-something', 'nine-year', 'gun-toting', 'young-ish', 'African-American', 'wide-open', 'take-no', 'eight-year'}
# 3836 {'nation-wide', '22-year', 'Jean-Baptiste'}
# 3837 {'voltage-controlled', 'single-celled', 'four-inch', 'two-way', 'cell-sized'}
# 3838 {'partisan-based', 'fact-checking', 'like-minded', 'evidence-based'}
# 3839 {'six-year', 'full-on', 'four-letter'}
# 3840 {'foot-wigglers', 'i-b', 'one-third', 'funny-sounding', 'o-l', 'o-g', 'One-third', 'T-r'}
# 3841 {'jewelry-designing', 'day-to', 'home-based', '25-meter', 'high-density', '12-meter', 'embroidery-stitching', 'papier-mâché', 'bangle-making'}
# 3842 {'mother-in', 'eco-generating', 'Douglas-Hamilton', '60-year', 'pollinator-friendly', 'two-acre', 'Elephant-Friendly', 'one-to', 'seven-ton', 'migratory-blocking', 'human-elephant', '50-to', 'hard-line'}
# 3844 {'stay-at', 'full-time', 'side-eye', 'short-term'}
# 3845 {'gut-driven', 'short-term', 'part-time', 'brand-new'}
# 3846 {'all-white', 'waist-high', 'long-lasting'}
# 3847 {'two-pronged', 'life-saving', 'petri-dishes', 'self-identify'}
# 3848 {'old-fashioned', 'fast-paced', 'high-tech', 'thank-you'}
# 3849 {'off-limits', 'end-all', 'auto-save', 'be-all', 'self-worth', 'long-term', 'short-term'}
# 3850 {'no-stakes', 'front-runner', 'make-or', 'earth-shattering', 'head-to', 'one-by', 'off-site', 'high-stakes', 'long-term', 'decision-making', 'built-in', 'low-stakes'}
# 3851 {'buy-in', 'four-part', 'problem-solving', 'micro-yes', 'brain-friendly'}
# 3852 {'front-load', 'time-management', 'all-nighters', 'long-lasting', 'problem-solving', 'self-worth'}
# 3853 {'over-emoters', 'well-being', 'work-related', 'half-digested', 'under-emoters', 'non-work'}
# 3854 {'small-business', '10-employee', 'zero-sum', 'brick-and', 'Malaysian-born', 'well-known', 'start-up', 'trade-off', 'trade-offs', 'e-learning', 'risk-free', 'ride-hailing'}
# 3855 {'cable-stayed', 'German-American', 'mid-19th', 'day-to'}
# 3856 {'role-played', 'six-year', 'self-preservation'}
# 3857 {'centuries-old', 'X-Man', 'curious-minded', 'high-level', 'mind-bogglingly', 'decades-experienced', 'Q-tip', 'ill-fated', 'Trans-Antarctic'}
# 3858 {'green-recessive', 'yellow-dominant', 'three-to', 'green-seeded', 'yellow-seeded', 'self-fertilize', 'yellow-colored'}
# 3859 {'five-dollar', 'eka-aluminum', 'eka-manganese', 't-shirts', 'two-letter', 'hall-of'}
# 3860 {'French-speaking', 'English-speaking'}
# 3861 {'anti-social'}
# 3862 {'M-D', 'anarcho-syndicalist', 'P-E', 'A-S'}
# 3864 {'self-doubt', 'anti-hero'}
# 3865 {'fail-safes', 'slow-growing', 'chemo-therapeutics', 'community-driven', 'fast-growing'}
# 3866 {'mass-scale', 'slut-shamed', 'reverse-searched', 'five-year', 'image-based', 'attention-seeking', 'victim-blamed', 'Image-based', 'see-through'}
# 3867 {'all-time', 'corticotropin-releasing', 'pea-sized', 'saber-tooth', 'acne-causing'}
# 3868 {'all-encompassing', 'jewel-encrusted', 'well-being'}
# 3869 {'story-telling'}
# 3870 {'top-down', 'bottom-up', 'self-decorate', 'mass-manufactured', 'Coca-Cola', 'well-being', 'far-reaching', 'self-decoration', 'mass-marketed', 'like-minded', 'mark-making'}
# 3871 {'Modern-day', 'forward-thinking'}
# 3872 {'ladle-looking', 'multi-tool'}
# 3873 {'so-called'}
# 3874 {'face-up', 'energy-efficient', 'no-nos'}
# 3875 {'hand-in', 'close-cropped'}
# 3876 {'mid-fifteenth', 'mass-produce'}
# 3877 {'7-Eleven', 'press-in', 'snap-on', 'single-use'}
# 3878 {'Merriam-Webster', 'five-or', '10-year', 'fan-made'}
# 3879 {'long-necked', 'ice-cream', 'whale-sized', 'tadpole-like', 'alligator-like', 'otter-like', '100-million', 'dinosaur-free', 'eel-like', 'saber-toothed', 'school-bus', 'ten-foot'}
# 3880 {'Pre-Second', 'Post-Second'}
# 3881 {'long-term', 'low-income', 'high-income'}
# 3882 {'co-parenting', 'co-parents', 'day-to', 'co-parent', 'prime-time', 'Co-parenting', 'pre-K', 'Co-parent', 'Fast-forward', 'self-absorbed', 'two-parent', 'hip-hop'}
# 3883 {'have-nots', 'state-owned', 'AI-powered', 'data-grabbing', 'U-B', 'D-I', 'brand-new', 'well-positioned', 'trade-off', 'start-ups', 'trade-offs', 'three-page', 'top-line', 'data-rich'}
# 3884 {'newly-discovered', 'modern-day', 'Jean-Baptiste', 'cross-species'}
# 3885 {'long-ships', 'sea-borne', 'well-known'}
# 3886 {'computer-generated', 'three-dimensional', '40-year', 'light-immersive', '360-degree', 'data-computing'}
# 3887 {'check-in', 'one-way', '40 - there', 'anti-white', 'anti-racist'}
# 3888 {'one-size', 'fits-all', 'sub-Saharan'}
# 3889 {'drug-free', 'well-earned', 'lappet-faced', 'man-made', 'mountain-dwelling'}
# 3890 {'life-threatening', 'heart-attack'}
# 3891 {'signed-off', 'self-stereotyping', 'job-related', 'feelings-based', 'two-thirds', 'minimum-wage', 'skills-related', 'fastest-growing', 'self-doubt', 'five-minute'}
# 3892 {'not-so', 'two-hat', 'time-tested', 'well-known', 'bottom-up', 'start-up', 'part-time', 'AI-enabled', 'online-offline', 'full-time', '10-plus'}
# 3893 {'Frankenstein-monster', 'industrial-strength', 'closed-captioned', 'Closed-captioned', 'life-forms', 'soul-sucking', 'Hair-cell', 'mind-expanding', 'Fast-forward', 'self-absorbed', 'lip-read'}
# 3894 {'tree-planting', 'anti-corruption', 'self-control', 'Seventy-three', 'Fifty-eight', 'self-confident'}
# 3895 {'in-between', 'self-amplifying', 'sci-fi', '22-lane', 'after-school', 'shape-shifters', 'Band-Aids', 'wake-up', 's-eye'}
# 3896 {'left-most', 'right-to', 'right-most'}
# 3897 {'V-2', 'freeze-dried', 'man-made', 'Apollo-Soyuz', 'R-7', 'last-ditch'}
# 3898 {'ice-covered', 'reached -89', 'double-whammy', 'as -40', 'cold-adapted', 'approximately -68'}
# 3899 {'Tissue-specific', 'tissue-specific', 'worn-out'}
# 3900 {'now-exhausted'}
# 3901 {'mid-century', 'semi-permanent', 'self-sufficient', 'single-family', 'long-term', 'hunter-gatherers'}
# 3902 {'human-readable', 'input-output'}
# 3903 {'f-r', 's-t', 'i-k', 'e-n', 'multi-sensory'}
# 3904 {'outside-in', 'right-hand', 'w-a', 'side-up', 'w-i', 'B-M'}
# 3906 {'nation-state', 'two-factor', 'men-spying', 'end-to', 'on-women'}
# 3907 {'co-opted', 'game-changing', 'one-on'}
# 3909 {'No-Side'}
# 3910 {'worst-case', 'animal-human', 'up-to', 'COVID-19', 'pre-existing'}
# 3911 {'big-ticket', 'well-informed', 'ill-conceived', 'Well-conceived', 'fact-checked', 'praise-worthy', 'pay-to', 'pony-show', 'once-great', 'dog-and', 'Democrat-Gazette', 'best-funded'}
# 3912 {'plug-in', 'like-minded', 'machine-like'}
# 3913 {'self-driving', 'space-suitable', 'near-real', 'far-off', 'one-billionth', 'GPS-like', 'ion-based'}
# 3914 {'fully-fed', 'natural-looking', 'single-celled', 'light-sensitive', 'hunger-driven', 'long-lasting', 'self-healing', 'anxiety-related', 'modern-day', 'self-report'}
# 3915 {'in-flight', 'on-board', 'life-saving', 'last-second'}
# 3916 {'well-being', 'sixty-one', 'Twenty-three'}
# 3917 {'four-hour', 'odd-numbered', 'un-amplified'}
# 3918 {'user-centered', 'meal-delivery', 'crab-shaped', 'start-ups', 'six-month', 'Winston-Salem', 'public-domain', 'three-to'}
# 3919 {'cross-dressing', 'man-woman', 'one-bedroom', 'two-sex', 'two-gender', 'free-loving', 'cross-dressed', 'mid-1990s', 'gender-variant', 'eight-year', 'long-standing'}
# 3920 {'symptom-free', 'middle-aged'}
# 3921 {'Judeo-Christian'}
# 3922 {'dark-skies'}
# 3923 {'bushy-tailed', 'Ta-Nehisi', 'N-word', 'six-letter', 'face-to', 'laser-focused', 'bright-eyed', 'run-in', 'second-guess'}
# 3925 {'8-year', 'believe - Often', 'believe - For'}
# 3926 {'worst-case', 'two-thirds', 'carbon-capture', 'silver-bullet', 'self-interest', 'cost-competitive'}
# 3927 {'back-and', 'snail-shaped', 'three-tenths', 'one-to', 'man-made', 'two-tenths', 'one-thirtieth'}
# 3928 {'science-based', 'COVID-19', 'Just-in', 'person-to', 'time-ordering', 'Asian-looking', 'self-interest'}
# 3929 {'mid-1980s', 'anti-depressants', 'life-threatening', 'anti-anxiety', 'drug-resistant'}
# 3930 {'two-thirds', 'off-limits', 'co-team', 'age-old', 'period-positive', 'napkin-shaped', 'deep-rooted', '15-year'}
# 3931 {'two-thirds', 'second-degree', 'tight-knit'}
# 3932 {'insect-borne', 'mild-mannered'}
# 3933 {'off-load', 'pattern-recognition', 'time-bound'}
# 3934 {'forty-nine', 'the-country', 'co-ops', 'Six-thousand', 'day-to', 'non-farmers', 'thirty-two', 'year-round', 'great-grandfather', 'renewable-energy', 'pick-your', 'co-op', 'all-of', 'first-in'}
# 3935 {'so-called', 'long-awaited', 'non-Christian'}
# 3936 {'single-handedly', 'climate-smart', 'well-being', 'sub-Saharan', 'kick-start'}
# 3937 {'cutting-edge', 'tune-up', 'second-order'}
# 3938 {'100-year', 'every-person', 'Martínez-Patiño', 'high-security', 'well-known', 'topsy-turvy', 'fast-forward'}
# 3939 {'multi-storied', 'city-states', 'cross-dressers', 'Naram-Sin', 'wedge-shaped'}
# 3940 {'fast-running', 'trillion-frame', 'self-driving', 'high-speed', 'low-power', 'of-sight', 'home-security', 'room-sized', 'ultra-high', 'real-time', 'per-second', 'non-line', 'eye-safe'}
# 3941 {'flood-prone', 'multi-pronged', 'the-art', '680-tonne', 'low-lying', '240-meter', 'state-of'}
# 3942 {'contact-trace', 'a-century', 'Korea-type', 'open-source', 'data-sharing', 'social-distance', 'self-swab', 'rich-world', 'five-day', 'human-to', 'sub-Saharan', 'better-known', 'private-sector', 'once-in'}
# 3943 {'go-to', 'day-to'}
# 3944 {'drug-induced', 'cognitive-behavioral', 're-emerging', 'short-lived'}
# 3945 {'30-year', 'out-of', 'part-time'}
# 3946 {'science-based'}
# 3947 {'zero-symptom', 'back-to', 'outbreak-based', 'so-called', '15-minute', 'measles-based', 'high-risk', 'best-placed', 'cost-effective', 'trade-offs', 'for-profit', 'RNA-based', 'long-term', 'one-health', '000-some'}
# 3948 {'top-down', 'SARS-like', 'mid-December', 'start-ups', 'Thirty-nine', 'post-SARS', 'point-of', 'post-lockdown', 'high-speed', 'US-China', 'Several-month', 'forty-day', 'social-distancing', 'two-month', 'human-to', 'self-quarantined', 'in-hospital', 'well-choreographed', 'flip-flopped', 'a-half', 'well-being', 'COVID-19', 'hand-washing', 'two-and', 'contact-tracing', 'temperature-check', 'self-quarantine', 'trace-testing', 'person-to', '11-million'}
# 3950 {'b-word', 'Late-night', 'belly-up', 'go-to', 'school-to', 'for-profit'}
# 3952 {'tricky-looking', 'life-support'}
# 3953 {'three-digit'}
# 3954 {'fair-skinned'}
# 3955 {'all-around', 'anxiety-producing', 'best-selling', '20-year', 'woo-woo', 'post-pandemic', 'first-ever', 'COVID-19', 'self-isolation', 'e-mailing', 'the-world', '360-degree', 'white-knuckled', 'future-tripping', 's-save', 'animal-tracking', 'half-lidded'}
# 3957 {'step-by'}
# 3958 {'six-month', 'front-facing', 'well-being', 'ping-ponging'}
# 3959 {'14-day', 'custom-made', 'longer-term', 'pandemic-resilient', 'op-eds', 'Petrie-Flom', 'contact-warning', 'self-defense', 'well-networked', 'policy-making', 'wide-scale', 'well-being', 'COVID-19', 'cross-disciplinary', 'trade-offs', 'contact-tracing', 'freedom-respecting', 'privacy-protection', 'privacy-protective', 'step-by', 'peer-to'}
# 3961 {'one-word', 'language-based', 'nimino-wiisin', 'nimino-naawakwe', 'self-government', 'church-run', 'self-esteem'}
# 3962 {'family-law', 'divorce-conscious', 'full-time', 'part-time'}
# 3963 {'non-toxic', 'self-medicate'}
# 3964 {'day-to', '60-40', 'zero-sum', 'penny-pinch', 'meat-and', 'Euro-dollar', 'long-term', 'one-off', 'wide-ranging', 'cause-effect', 'not-leverage', '1930-45', 'big-picture', 'big-money', 'trade-offs', 'double-digit', 'cost-effectively', 'self-sufficiency', 'short-term', 'well-educated', 'broad-ranging', 'low-paid', 'decision-making', 'self-perpetuating'}
# 3965 {'water-based', 'light-years', 'star- and', 'high-resolution', 'planet-forming', 'single-pixel', 'mile-sized', 'low-resolution', 'just-right', 'not-too'}
# 3966 {'whites-only', 'twenty-four', 'eighty-one', 'high-profile', 'one-woman'}
# 3967 {'awe-inspiring', 'alien-looking', 'long-range', 'donut-shaped'}
# 3968 {'end-to', 'three-unit'}
# 3969 {'crushed-up', 'life-enriching', 'well-being', 'hands-on'}
# 3970 {'self-similarity'}
# 3971 {'middle-class', 'zero-sum', 'French-Canadian', 'auto-factory', '30-year', 'home-ownership', 'a-barrel', 'crab-in', 'fixed-rate', 'call-in'}
# 3972 {'co-parenting', 'shout-out', 'well-behaved', 'co-parents', 'on-again', 'pick-up', 'drop-off', 'co-parent', '19-year', 'two-sided', 'hand-picked', 'second-degree', 'Post-traumatic', 'off-again'}
# 3973 {'Woo-hoo', 'Tay-Sachs', 'disease-causing', 'full-on', 'non-Jews', 'European-born'}
# 3974 {'non-narrative', 'breath-taking'}
# 3975 {'self-critical', 'self-image', 'low-wage', 'entry-level', 'self-control', 'eight-year'}
# 3976 {'next-level', 'day-to', 'COVID-19', 'self-sustaining'}
# 3977 {'self-focused', 'zero-year', 'every-day', 'carved-up', 'large-scale'}
# 3978 {'all-time', 'two-thirds', 'mass-produce', 'eco-friendly', 'labor-intensive', 'rubber-soled', 'one-fifth'}
# 3979 {'just - No', 'situation - everybody', 'parents - bastards', 'me - who', 'react - and', 'horse - or', 'happens - but', 'here - this'}
# 3980 {'eco-friendly', '50-meter', '2-minute', 'low-pollution'}
# 3981 {'contact-trace', 'Fuji-like', 'COVID-19', 'two-month', 'long-term'}
# 3982 {'self-harm', 'risk-assess', 'high-risk', 'stack-rank', 'middle-of', 'the-night', 'time-zone', 'user-friendly', '30-hour', 'full-time'}
# 3983 {'mid-twentieth', 'visual-spatial', 'large-scale', 'problem-solving'}
# 3984 {'cash-only', 'class-action', 'crime-fighting', 'headline-grabbing'}
# 3985 {'five-year', 'mid-20s'}
# 3986 {'gel-like', 'spiny-skinned', 'counter-attacks', 'lung-like', 'deep-sea', 'sausage-shaped'}
# --fin--

# %%
tedtalks.transcript[1630]
# Out:
# "I work with children with autism. Specifically, I make technologies to help them communicate. Now, many of the problems that children with autism face, they have a common source, and that source is that they find it difficult to understand abstraction, symbolism. And because of this, they have a lot of difficulty with language. Let me tell you a little bit about why this is. You see that this is a picture of a bowl of soup. All of us can see it. All of us understand this. These are two other pictures of soup, but you can see that these are more abstract These are not quite as concrete. And when you get to language, you see that it becomes a word whose look, the way it looks and the way it sounds, has absolutely nothing to do with what it started with, or what it represents, which is the bowl of soup. So it's essentially a completely abstract, a completely arbitrary representation of something which is in the real world, and this is something that children with autism have an incredible amount of difficulty with. Now that's why most of the people that work with children with autism — speech therapists, educators — what they do is, they try to help children with autism communicate not with words, but with pictures. So if a child with autism wanted to say, I want soup, that child would pick three different pictures, I, want, and soup, and they would put these together, and then the therapist or the parent would understand that this is what the kid wants to say. And this has been incredibly effective; for the last 30, 40 years people have been doing this. In fact, a few years back, I developed an app for the iPad which does exactly this. It's called Avaz, and the way it works is that kids select different pictures. These pictures are sequenced together to form sentences, and these sentences are spoken out. So Avaz is essentially converting pictures, it's a translator, it converts pictures into speech. Now, this was very effective. There are thousands of children using this, you know, all over the world, and I started thinking about what it does and what it doesn't do. And I realized something interesting: Avaz helps children with autism learn words. What it doesn't help them do is to learn word patterns. Let me explain this in a little more detail. Take this sentence: I want soup tonight. Now it's not just the words here that convey the meaning. It's also the way in which these words are arranged, the way these words are modified and arranged. And that's why a sentence like I want soup tonight is different from a sentence like Soup want I tonight, which is completely meaningless. So there is another hidden abstraction here which children with autism find a lot of difficulty coping with, and that's the fact that you can modify words and you can arrange them to have different meanings, to convey different ideas. Now, this is what we call grammar. And grammar is incredibly powerful, because grammar is this one component of language which takes this finite vocabulary that all of us have and allows us to convey an infinite amount of information, an infinite amount of ideas. It's the way in which you can put things together in order to convey anything you want to. And so after I developed Avaz, I worried for a very long time about how I could give grammar to children with autism. The solution came to me from a very interesting perspective. I happened to chance upon a child with autism conversing with her mom, and this is what happened. Completely out of the blue, very spontaneously, the child got up and said, Eat. Now what was interesting was the way in which the mom was trying to tease out the meaning of what the child wanted to say by talking to her in questions. So she asked, Eat what? Do you want to eat ice cream? You want to eat? Somebody else wants to eat? You want to eat cream now? You want to eat ice cream in the evening? And then it struck me that what the mother had done was something incredible. She had been able to get that ...

# %%
tedtalks.transcript.str.count('.')
# Out:
# 0       11499
# 1       17251
# 2       17673
# 3       18083
# 4       16981
#         ...
# 3982     9695
# 3983     4810
# 3984     9418
# 3985     4010
# 3986     4022
# Name: transcript, Length: 3987, dtype: int64

# %%
pd.read_csv('~/data/ted_talks_en.csv').transcript[2173]
# Out:
# "I've been living in rural East Africa for about 10 years, and I want to share a field perspective with you on global poverty. I believe that the greatest failure of the human race is the fact that we've left more than one billion of our members behind. Hungry, extreme poverty: these often seem like gigantic, insurmountable problems, too big to solve. But as a field practitioner, I believe these are actually very solvable problems if we just take the right strategies. Archimedes was an ancient Greek thinker, and he taught us that if we lean on the right levers, we can move the world. In the fight against extreme poverty, I believe there are three powerful levers that we can lean on. This talk is all about those levers, and why they make poverty a winnable fight in our lifetimes. What is extreme poverty? When I first moved to rural East Africa, I stayed overnight with a farm family. They were wonderful people. They invited me into their home. We sang songs together and ate a simple dinner. They gave me a blanket to sleep on the floor. In the morning, however, there was nothing to eat. And then at lunchtime, I watched with an increasingly sick feeling as the eldest girl in the family cooked porridge as a substitute for lunch. For that meal, every child drank one cup to survive. And I cannot tell you how ashamed I felt when they handed one of those cups to me, and I knew I had to accept their hospitality. Children need food not only to survive but also to grow physically and mentally. Every day they fail to eat, they lose a little bit of their future. Amongst the extreme poor, one in three children are permanently stunted from a lifetime of not eating enough. When that's combined with poor access to health care, one in 10 extremely poor children die before they reach age five. And only one quarter of children complete high school because they lack school fees. Hunger and extreme poverty curb human potential in every possible way. We see ourselves as a thinking, feeling and moral human race, but until we solve these problems for all of our members, we fail that standard, because every person on this planet matters. This child matters. These children matter. This girl matters. You know, we see things like this, and we're upset by them, but they seem like such big problems. We don't know how to take effective action. But remember our friend Archimedes. Global poverty has powerful levers. It's a problem like any other. I live and work in the field, and as a practitioner, I believe these are very solvable problems. So for the next 10 minutes, let's not be sad about the state of the world. Let's engage our brains. Let's engage our collective passion for problem-solving and figure out what those levers are. Lever number one: most of the world's poor are farmers. Think about how extraordinary this is. If this picture represents the world's poor, then more than half engage in farming as a major source of income. This gets me really excited. All of these people, one profession. Think how powerful this is. When farmers become more productive, then more than half the world's poor earn more money and climb out of poverty. And it gets better. The product of farming is, of course, food. So when farmers become more productive, they earn more food, and they don't just help themselves, but they help to feed healthy communities and thriving economies. And when farmers become more productive, they reduce environmental pressure. We only have two ways we can feed the world: we can either make our existing farmland a lot more productive, or we can clear cut forest and savannah to make more farmland, which would be environmentally disastrous. Farmers are basically a really important leverage point. When farmers become more productive, they earn more income, they climb out of poverty, they feed their communities and they reduce environmental land pressure. Farmers stand at the center of the world. And not a farmer like this one, but rather this lady. Mos ...

# %% [markdown]
# # Load OpenSubtitles.csv

# %%
from datasets import load_dataset
opensub=load_dataset('csv',data_files='/home/nxingyu/data/opensubtitles.csv')
# Out:
# Using custom data configuration default
# Downloading and preparing dataset csv/default-31343ecce9569509 (download: Unknown size, generated: Unknown size, post-processed: Unknown size, total: Unknown size) to /home/nxingyu/.cache/huggingface/datasets/csv/default-31343ecce9569509/0.0.0/2960f95a26e85d40ca41a230ac88787f715ee3003edaacb8b1f0891e9f04dda2...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0), HTML(value=''…
# Dataset csv downloaded and prepared to /home/nxingyu/.cache/huggingface/datasets/csv/default-31343ecce9569509/0.0.0/2960f95a26e85d40ca41a230ac88787f715ee3003edaacb8b1f0891e9f04dda2. Subsequent calls will reuse this data.

# %%
opensub=pd.read_csv('/home/nxingyu/data/open_subtitles_processed.csv',dtype='string')

# %%
opensub[opensub.talk_id.map(lambda x:x.split('/')[4]=='1990')].transcript.apply(removespeakertags)
# Out:
# 20721    Alright Suzi are you ready? Just a little bit ...
# 20722    Don't worry. You don't trust me? I got the mon...
# 20723    The details. Terrifying. I think malibu barbie...
# 20724    - Good morning - Good morning, Uncle Wong. Dra...
# 20725     Brakes Hissing Woman Narrating Her name was O...
#                                ...
# 21480    VIGOUR You keep driving but we're not getting ...
# 21481    WOMAN: Shall I tell you my dream? I dreamt I w...
# 21482    My name is Lam Pik Seng, I'm 1 7 years old I w...
# 21483    Aah!. which was at first thought to be the sit...
# 21484    Get your money ready please. That's 143 rouble...
# Name: transcript, Length: 764, dtype: object

# %%
tedtalks.transcript.map(lambda x:x[-4:])
# Out:
# 0       it.
# 1       ch.
# 2       ar!
# 3       os!
# 4       ch.
#         ...
# 3982    .org
# 3983    ore.
# 3984    ou.
# 3985    il.
# 3986    utt.
# Name: transcript, Length: 3987, dtype: object

# %%
def punct_proportion(df):
    l=[]
    for c in ".?!,;:-—":
        l.append(sum(df.transcript.str.count("\\"+c)))
    [print(i[0],i[1],i[1]/sum(l)) for i in zip(list(".?!,;:-—"),l)]
punct_proportion(tedtalks)
# Out:
# . 410157 0.3962796818222661
# ? 36774 0.035529782545054726
# ! 3277 0.003166125452769466
# , 494575 0.477841469576887
# ; 5846 0.005648205491879859
# : 12950 0.012511847608594626
# - 38065 0.036777102642560185
# — 33375 0.03224578485998808

# %%
tedtalks = pd.read_csv('~/data/ted_talks_processed.csv')[['talk_id','transcript']].sample(frac=1,random_state=42).reset_index(drop=True)
split_1=int(0.8 * len(tedtalks))
split_2=int(0.9 * len(tedtalks))
tedtalks_train = tedtalks[:split_1]
tedtalks_dev = tedtalks[split_1:split_2]
tedtalks_test = tedtalks[split_2:]

# %%
for split in tedtalks_train, tedtalks_dev, tedtalks_test:
    punct_proportion(split)
    print()
# Out:
# . 328524 0.3951103702581199
# ? 29405 0.03536490617866584
# ! 2698 0.0032448398867553287
# , 397931 0.47858501889415667
# ; 4770 0.005736799948044076
# : 10394 0.012500691542970677
# - 30778 0.03701619052429781
# — 26974 0.03244118276698971
#
# . 42582 0.40382755154296984
# ? 3825 0.03627449120877037
# ! 278 0.002636420537526317
# , 49507 0.46950097680329267
# ; 602 0.0057090833222692185
# : 1342 0.01272689338618819
# - 3813 0.036160688883409516
# — 3497 0.03316389431557385
#
# . 39051 0.39807745236954506
# ? 3544 0.03612676989571759
# ! 301 0.0030683289330166465
# , 47137 0.48050438842393906
# ; 474 0.004831853535713922
# : 1214 0.012375253570372786
# - 3474 0.03541320502757418
# — 2904 0.029602748244120736

# %%
# import os
paths=os.path.splitext('test.csv')
paths[0]+'.test'+paths[1]
# Out:
# 'test.test.csv'
